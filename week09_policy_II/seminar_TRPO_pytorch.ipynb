# %%
import sys, os
if 'google.colab' in sys.modules and not os.path.exists('.setup_complete'):
    # !wget -q https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/setup_colab.sh -O- | bash

    # !pip install -q gymnasium

    # !touch .setup_complete

# This code creates a virtual display to draw game images on.
# It will have no effect if your machine has a monitor.
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY")) == 0:
    # !bash ../xvfb start
    os.environ['DISPLAY'] = ':1'
# Out:
# Starting virtual X frame buffer: Xvfb../xvfb: line 24: start-stop-daemon: command not found
# .

# %% [markdown]
# ### Let's make a TRPO!
#
# In this notebook we will write the code of the one Trust Region Policy Optimization.
# As usually, it contains a few different parts which we are going to reproduce.

# %%
from typing import Tuple
from base64 import b64encode
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

import matplotlib.pyplot as plt
from pathlib import Path
from typing import Optional
# %matplotlib inline

# %%
import gymnasium as gym

env = gym.make("Acrobot-v1", render_mode="rgb_array")
env.reset()
observation_shape = env.observation_space.shape
n_actions = env.action_space.n

print("Observation Space", env.observation_space)
print("Action Space", env.action_space)
# Out:
# Observation Space Box([ -1.        -1.        -1.        -1.       -12.566371 -28.274334], [ 1.        1.        1.        1.       12.566371 28.274334], (6,), float32)
# Action Space Discrete(3)

# %%
plt.imshow(env.render())

# %% [markdown]
# ### Step 1: Defining a network
#
# With all it's complexity, at it's core TRPO is yet another policy gradient method.
#
# This essentially means we're actually training a stochastic policy $\pi_\theta \left( a \middle| s \right)$.
#
# And yes, it's gonna be a neural network. So let's start by defining one.

# %%
class TRPOAgent(nn.Module):
    def __init__(self, state_shape: Tuple[int], n_actions: int):
        '''
        Here you should define your model
        You should have LOG-PROBABILITIES as output because you will need it to compute loss
        We recommend that you start simple:
        use 1-2 hidden layers with 100-500 units and relu for the first try
        '''
        super().__init__()

        assert isinstance(state_shape, tuple)
        assert len(state_shape) == 1
        input_dim = state_shape[0]
        hid_dim = 1024
        # Prepare your model here.
        self.policy = nn.Sequential(
            nn.Linear(input_dim, hid_dim),
            nn.ReLU(),
            nn.Linear(hid_dim, hid_dim),
            nn.ReLU(),
            nn.Linear(hid_dim, n_actions)
        )

    def forward(self, states: torch.Tensor):
        """
        takes agent's observation, returns log-probabilities
        :param state_t: a batch of states, shape = [batch_size, state_shape]
        """

        # Use your network to compute log_probs for the given states.
        logits = self.policy(states)
        log_probs = torch.nn.functional.log_softmax(logits, dim=1)

        return log_probs

    def get_log_probs(self, states: torch.Tensor):
        '''
        Log-probs for training
        '''
        return self.forward(states)

    def get_probs(self, states: torch.Tensor):
        '''
        Probs for interaction
        '''
        return torch.exp(self.forward(states))

    def act(self, obs: np.ndarray, sample: bool = True):
        '''
        Samples action from policy distribution (sample = True) or takes most likely action (sample = False)
        :param: obs - single observation vector
        :param sample: if True, samples from \pi, otherwise takes most likely action
        :returns: action (single integer) and probabilities for all actions
        '''

        with torch.no_grad():
            probs = self.get_probs(torch.tensor(obs[np.newaxis], dtype=torch.float32)).numpy()

        if sample:
            action = int(np.random.choice(n_actions, p=probs[0]))
        else:
            action = int(np.argmax(probs))

        return action, probs[0]


agent = TRPOAgent(observation_shape, n_actions)
# Out:
# <>:52: SyntaxWarning: invalid escape sequence '\p'
# <>:52: SyntaxWarning: invalid escape sequence '\p'
# /var/folders/6_/gwk723d11tz3jmpqhzydnpfh0000gn/T/ipykernel_95876/1339467068.py:52: SyntaxWarning: invalid escape sequence '\p'
#   :param sample: if True, samples from \pi, otherwise takes most likely action

# %%
# Check if log-probabilities satisfies all the requirements
log_probs = agent.get_log_probs(torch.tensor(env.reset()[0][np.newaxis], dtype=torch.float32))
assert (
    isinstance(log_probs, torch.Tensor) and
    log_probs.requires_grad
), "log_probs must be a torch.Tensor with grad"
assert log_probs.shape == (1, n_actions)
sums = torch.exp(log_probs).sum(dim=1)
assert torch.allclose(sums, torch.ones_like(sums))

# Demo use
print("sampled:", [agent.act(env.reset()[0]) for _ in range(5)])
print("greedy:", [agent.act(env.reset()[0], sample=False) for _ in range(5)])
# Out:
# sampled: [(2, array([0.3454564 , 0.31951487, 0.33502877], dtype=float32)), (1, array([0.3447768 , 0.31877947, 0.33644366], dtype=float32)), (1, array([0.3426341 , 0.31957364, 0.33779222], dtype=float32)), (2, array([0.3438874 , 0.31985578, 0.33625677], dtype=float32)), (1, array([0.34523684, 0.3186007 , 0.3361624 ], dtype=float32))]
# greedy: [(0, array([0.3454981 , 0.31913966, 0.33536214], dtype=float32)), (0, array([0.34416652, 0.31962845, 0.336205  ], dtype=float32)), (0, array([0.34466398, 0.31953418, 0.3358019 ], dtype=float32)), (0, array([0.34528857, 0.3193976 , 0.3353138 ], dtype=float32)), (0, array([0.34469414, 0.31924728, 0.33605844], dtype=float32))]

# %% [markdown]
# #### Flat parameters operations
#
# We are going to use it

# %%
def get_flat_params_from(model):
    params = [torch.ravel(param.detach()) for param in model.parameters()]
    flat_params = torch.cat(params)
    return flat_params


def set_flat_params_to(model, flat_params):
    prev_ind = 0
    for param in model.parameters():
        flat_size = int(np.prod(list(param.shape)))
        param.data.copy_(
            flat_params[prev_ind:prev_ind + flat_size].reshape(param.shape)
        )
        prev_ind += flat_size

# %% [markdown]
# Compute cumulative reward just like you did in vanilla REINFORCE

# %%
import scipy.signal


def get_cumulative_returns(r, gamma=1):
    """
    Computes cumulative discounted rewards given immediate rewards
    G_i = r_i + gamma*r_{i+1} + gamma^2*r_{i+2} + ...
    Also known as R(s,a).
    """
    r = np.array(r)
    assert r.ndim >= 1
    return scipy.signal.lfilter([1], [1, -gamma], r[::-1], axis=0)[::-1]

# %%
# simple demo on rewards [0,0,1,0,0,1]
get_cumulative_returns([0, 0, 1, 0, 0, 1], gamma=0.9)
# Out:
# array([1.40049, 1.5561 , 1.729  , 0.81   , 0.9    , 1.     ])

# %% [markdown]
# **Rollout**

# %%
def rollout(env, agent, max_pathlength=2500, n_timesteps=50000):
    """
    Generate rollouts for training.
    :param: env - environment in which we will make actions to generate rollouts.
    :param: act - the function that can return policy and action given observation.
    :param: max_pathlength - maximum size of one path that we generate.
    :param: n_timesteps - total sum of sizes of all pathes we generate.
    """
    paths = []

    total_timesteps = 0
    while total_timesteps < n_timesteps:
        obervations, actions, rewards, action_probs = [], [], [], []
        obervation, _ = env.reset()
        for _ in range(max_pathlength):
            action, policy = agent.act(obervation)
            obervations.append(obervation)
            actions.append(action)
            action_probs.append(policy)
            obervation, reward, terminated, truncated, _ = env.step(action)
            rewards.append(reward)
            total_timesteps += 1
            if terminated or truncated or total_timesteps >= n_timesteps:
                path = {
                    "observations": np.array(obervations),
                    "policy": np.array(action_probs),
                    "actions": np.array(actions),
                    "rewards": np.array(rewards),
                    "cumulative_returns": get_cumulative_returns(rewards),
                }
                paths.append(path)
                break
    return paths

# %%
from pprint import pprint

paths = rollout(env, agent, max_pathlength=5, n_timesteps=100)
pprint(paths[-1])

assert (paths[0]['policy'].shape == (5, n_actions))
assert (paths[0]['cumulative_returns'].shape == (5,))
assert (paths[0]['rewards'].shape == (5,))
assert (paths[0]['observations'].shape == (5,) + observation_shape)
assert (paths[0]['actions'].shape == (5,))

print("It's ok")
# Out:
# {'actions': array([2, 0, 1, 2, 0]),
#  'cumulative_returns': array([-5., -4., -3., -2., -1.]),
#  'observations': array([[ 0.99756426,  0.0697538 ,  0.99721706,  0.07455303,  0.02078394,
#          0.07331705],
#        [ 0.99856687,  0.05351868,  0.9925787 ,  0.12160394, -0.17837211,
#          0.38829288],
#        [ 0.99958676,  0.02874599,  0.98816246,  0.15341125, -0.06387565,
#         -0.07578866],
#        [ 0.9998763 ,  0.01572576,  0.99209094,  0.125521  , -0.06452417,
#         -0.20313638],
#        [ 0.99995285, -0.00970904,  0.99407446,  0.10870122, -0.185063  ,
#          0.03245858]], dtype=float32),
#  'policy': array([[0.3429394 , 0.319321  , 0.3377396 ],
#        [0.33932438, 0.3195842 , 0.3410914 ],
#        [0.34422165, 0.3196235 , 0.33615488],
#        [0.34502748, 0.32072943, 0.33424312],
#        [0.34328303, 0.3195706 , 0.33714634]], dtype=float32),
#  'rewards': array([-1., -1., -1., -1., -1.])}
# It's ok

# %% [markdown]
# ### Step 3: Auxiliary functions
#
# Now let's define the loss functions and something else for actual TRPO training.

# %% [markdown]
# The surrogate reward should be:
# $$J_{surr}= {1 \over N} \sum\limits_{i=1}^N \frac{\pi_{\theta}(s_i, a_i)}{\pi_{\theta_{old}}(s_i, a_i)}A_{\theta_{old}(s_i, a_i)}$$
#
# For simplicity, in this assignment we are going to use cumulative rewards instead of advantage:
# $$J'_{surr}= {1 \over N} \sum\limits_{i=1}^N \frac{\pi_{\theta}(s_i, a_i)}{\pi_{\theta_{old}}(s_i, a_i)}G_{\theta_{old}(s_i, a_i)}$$
#
# Since we want to maximize the reward, we are going to minimize the corresponding surrogate loss:
# $$ L_{surr} = - J'_{surr} $$

# %%
def get_loss(agent, observations, actions, cumulative_returns, old_probs):
    """
    Computes TRPO objective
    :param: observations - batch of observations [timesteps x state_shape]
    :param: actions - batch of actions [timesteps]
    :param: cumulative_returns - batch of cumulative returns [timesteps]
    :param: old_probs - batch of probabilities computed by old network [timesteps x num_actions]
    :returns: scalar value of the objective function
    """
    batch_size = observations.shape[0]
    probs_all = agent.get_probs(observations)

    probs_for_actions = probs_all[torch.arange(batch_size), actions]
    old_probs_for_actions = old_probs[torch.arange(batch_size), actions]

    ratio = (probs_for_actions / old_probs_for_actions)
    # Compute surrogate loss, aka importance-sampled policy gradient
    loss = -(ratio * cumulative_returns).mean()
    assert loss.ndim == 0
    return loss

# %% [markdown]
# We can ascend these gradients as long as our $\pi_\theta(a|s)$ satisfies the constraint
# $$\mathbb{E}_{s,\pi_{\theta_{t}}} \Big[ \operatorname{KL} \left( \pi_{\theta_{t}} (s) \:\|\: \pi_{\theta_{t+1}} (s) \right) \Big] < \alpha$$
#
#
# where
#
# $$\operatorname{KL} \left( p \| q \right) = \mathbb{E}_p \log \left( \frac p q \right)$$

# %%
def get_kl(agent, observations, actions, cumulative_returns, old_probs):
    """
    Computes KL-divergence between network policy and old policy
    :param: observations - batch of observations [timesteps x state_shape]
    :param: actions - batch of actions [timesteps]
    :param: cumulative_returns - batch of cumulative returns [timesteps] (we don't need it actually)
    :param: old_probs - batch of probabilities computed by old network [timesteps x num_actions]
    :returns: scalar value of the KL-divergence
    """
    batch_size = observations.shape[0]
    log_probs_all = agent.get_log_probs(observations)
    probs_all = torch.exp(log_probs_all)

    # Compute Kullback-Leibler divergence (see formula above).
    # Note: you need to sum KL and entropy over all actions, not just the ones agent took.
    # You will also need to compute max KL over all timesteps.
    old_log_probs = torch.log(old_probs + 1e-10)

    kl = (old_probs * (old_log_probs - log_probs_all)).sum(dim=1).mean()

    assert kl.ndim == 0
    assert (kl > -0.0001).all() and (kl < 10000).all()
    return kl

# %%
def get_entropy(agent, observations):
    """
    Computes entropy of the network policy
    :param: observations - batch of observations
    :returns: scalar value of the entropy
    """

    observations = torch.tensor(observations, dtype=torch.float32)

    log_probs_all = agent.get_log_probs(observations)
    probs_all = torch.exp(log_probs_all)

    entropy = (-probs_all * log_probs_all).sum(dim=1).mean(dim=0)

    assert entropy.ndim == 0
    return entropy

# %% [markdown]
# **Linear search**
#
# TRPO in its core involves ascending surrogate policy gradient constrained by KL divergence.
#
# In order to enforce this constraint, we're gonna use linesearch. You can find out more about it [here](https://en.wikipedia.org/wiki/Linear_search)

# %%
def linesearch(f, x: torch.Tensor, fullstep: torch.Tensor, max_kl: float, max_backtracks: int = 10, backtrack_coef: float = 0.5):
    """
    Linesearch finds the best parameters of neural networks in the direction of fullstep contrainted by KL divergence.
    :param: f - function that returns loss, kl and arbitrary third component.
    :param: x - old parameters of neural network.
    :param: fullstep - direction in which we make search.
    :param: max_kl - constraint of KL divergence.
    :returns:
    """
    loss, _, = f(x)
    for stepfrac in backtrack_coef**np.arange(max_backtracks):
        xnew = x + stepfrac * fullstep
        new_loss, kl = f(xnew)
        if kl <= max_kl and new_loss < loss:
            x = xnew
            loss = new_loss
    return x

# %% [markdown]
# **Conjugate gradients**
#
# Since TRPO includes contrainted optimization, we will need to solve $A x = b$ using conjugate gradients.
#
# In general, CG is an algorithm that solves $A x = b$ where $A$ is positive-defined. $A$ is the Hessian matrix so $A$ is positive-defined. You can find out more about CG [here](https://en.wikipedia.org/wiki/Conjugate_gradient_method).

# %%
def conjugate_gradient(f_Ax, b, cg_iters=10, residual_tol=1e-10):
    """
    This method solves system of equation Ax=b using an iterative method called conjugate gradients
    :f_Ax: function that returns Ax
    :b: targets for Ax
    :cg_iters: how many iterations this method should do
    :residual_tol: epsilon for stability
    """
    p = b.clone()
    r = b.clone()
    x = torch.zeros_like(b)
    rdotr = torch.sum(r*r)
    for i in range(cg_iters):
        z = f_Ax(p)
        v = rdotr / (torch.sum(p*z) + 1e-8)
        x += v * p
        r -= v * z
        newrdotr = torch.sum(r*r)
        mu = newrdotr / (rdotr + 1e-8)
        p = r + mu * p
        rdotr = newrdotr
        if rdotr < residual_tol:
            break
    return x

# %%
# This code validates conjugate gradients
A = np.random.rand(8, 8)
A = A.T @ A


def f_Ax(x):
    return torch.ravel(torch.tensor(A, dtype=torch.float32) @ x.reshape(-1, 1))


b = np.random.rand(8)
w = (np.linalg.inv(A.T @ A) @ A.T @ b.reshape(-1, 1)).reshape(-1)

print(w)
print(conjugate_gradient(f_Ax, torch.tensor(b, dtype=torch.float32)).numpy())
# Out:
# [ -63.00611294 -105.4994759    93.01992103  230.75939385 -193.90485711
#    56.25133937  -37.14211381  136.361437  ]
# [ -63.013435 -105.50681    93.03051   230.76425  -193.91327    56.25587
#   -37.14415   136.37292 ]

# %% [markdown]
# ### Step 4: training
# In this section we construct the whole update step function.

# %%
def update_step(agent, observations, actions, cumulative_returns, old_probs, max_kl):
    """
    This function does the TRPO update step
    :param: observations - batch of observations
    :param: actions - batch of actions
    :param: cumulative_returns - batch of cumulative returns
    :param: old_probs - batch of probabilities computed by old network
    :param: max_kl - controls how big KL divergence may be between old and new policy every step.
    :returns: KL between new and old policies and the value of the loss function.
    """

    # Here we prepare the information
    observations = torch.tensor(observations, dtype=torch.float32)
    actions = torch.tensor(actions, dtype=torch.int64)
    cumulative_returns = torch.tensor(cumulative_returns, dtype=torch.float32)
    old_probs = torch.tensor(old_probs, dtype=torch.float32)

    # Here we compute gradient of the loss function
    loss = get_loss(agent, observations, actions, cumulative_returns, old_probs)
    grads = torch.autograd.grad(loss, agent.parameters())
    loss_grad = torch.cat([torch.ravel(grad.detach()) for grad in grads])

    def Fvp(v):
        # Here we compute Fx to do solve Fx = g using conjugate gradients
        # We actually do here a couple of tricks to compute it efficiently

        kl = get_kl(agent, observations, actions, cumulative_returns, old_probs)

        grads = torch.autograd.grad(kl, agent.parameters(), create_graph=True)
        flat_grad_kl = torch.cat([grad.reshape(-1) for grad in grads])

        kl_v = (flat_grad_kl * v).sum()
        grads = torch.autograd.grad(kl_v, agent.parameters())
        flat_grad_grad_kl = torch.cat([torch.ravel(grad) for grad in grads]).detach()

        return flat_grad_grad_kl + v * 0.1

    # Here we solve Fx = g system using conjugate gradients
    stepdir = conjugate_gradient(Fvp, -loss_grad, 10)

    # Here we compute the initial vector to do linear search
    shs = 0.5 * (stepdir * Fvp(stepdir)).sum(0, keepdim=True)

    lm = torch.sqrt(shs / max_kl)
    fullstep = stepdir / lm[0]

    neggdotstepdir = (-loss_grad * stepdir).sum(0, keepdim=True)

    # Here we get the start point
    prev_params = get_flat_params_from(agent)

    def get_loss_kl(params):
        # Helper for linear search
        set_flat_params_to(agent, params)
        return [
            get_loss(agent, observations, actions, cumulative_returns, old_probs),
            get_kl(agent, observations, actions, cumulative_returns, old_probs),
        ]

    # Here we find our new parameters
    new_params = linesearch(get_loss_kl, prev_params, fullstep, max_kl)

    # And we set it to our network
    set_flat_params_to(agent, new_params)

    return get_loss_kl(new_params)

# %% [markdown]
# ### Step 5: Main TRPO loop
#
# Here we will train our network!

# %%
import time
from itertools import count

# TRPO hyperparameter; controls how big KL divergence may be between the old and the new policy at every step.
max_kl = 0.01
numeptotal = 0  # Number of episodes we have completed so far.

start_time = time.time()

for i in count(1):
    print("\n********** Iteration %i ************" % i)

    # Generating paths.
    print("Rollout")
    paths = rollout(env, agent)
    print("Made rollout")

    # Updating policy.
    observations = np.concatenate([path["observations"] for path in paths])
    actions = np.concatenate([path["actions"] for path in paths])
    returns = np.concatenate([path["cumulative_returns"] for path in paths])
    old_probs = np.concatenate([path["policy"] for path in paths])

    loss, kl = update_step(agent, observations, actions, returns, old_probs, max_kl)

    # Report current progress
    episode_rewards = np.array([path["rewards"].sum() for path in paths])

    stats = {}
    numeptotal += len(episode_rewards)
    stats["Total number of episodes"] = numeptotal
    stats["Average sum of rewards per episode"] = episode_rewards.mean()
    stats["Std of rewards per episode"] = episode_rewards.std()
    stats["Time elapsed"] = "%.2f mins" % ((time.time() - start_time)/60.)
    stats["KL between old and new distribution"] = kl.data.numpy()
    stats["Entropy"] = get_entropy(agent, observations).data.numpy()
    stats["Surrogate loss"] = loss.data.numpy()
    for k, v in stats.items():
        print(k + ": " + " " * (40 - len(k)) + str(v))
# Out:
# ********** Iteration 1 ************
# Rollout
# Made rollout
# Total number of episodes:                 100
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             0.15 mins
# KL between old and new distribution:      0.009985578
# Entropy:                                  0.99865633
# Surrogate loss:                           249.85835
#
# ********** Iteration 2 ************
# Rollout
# Made rollout
# Total number of episodes:                 200
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             0.30 mins
# KL between old and new distribution:      0.009986519
# Entropy:                                  0.9748517
# Surrogate loss:                           249.45172
#
# ********** Iteration 3 ************
# Rollout
# Made rollout
# Total number of episodes:                 300
# Average sum of rewards per episode:       -500.0
# Std of rewards per episode:               0.0
# Time elapsed:                             0.45 mins
# KL between old and new distribution:      0.009989493
# Entropy:                                  0.97284484
# Surrogate loss:                           249.79672
#
# ********** Iteration 4 ************
# Rollout
# Made rollout
# Total number of episodes:                 401
# Average sum of rewards per episode:       -495.029702970297
# Std of rewards per episode:               39.9369442217749
# Time elapsed:                             0.60 mins
# KL between old and new distribution:      0.0099893985
# Entropy:                                  0.97339326
# Surrogate loss:                           248.8764
#
# ********** Iteration 5 ************
# Rollout
# Made rollout
# Total number of episodes:                 503
# Average sum of rewards per episode:       -490.03921568627453
# Std of rewards per episode:               36.39541060505214
# Time elapsed:                             0.75 mins
# KL between old and new distribution:      0.009983898
# Entropy:                                  0.96958333
# Surrogate loss:                           245.6988
#
# ********** Iteration 6 ************
# Rollout
# Made rollout
# Total number of episodes:                 603
# Average sum of rewards per episode:       -499.99
# Std of rewards per episode:               0.09949874371066196
# Time elapsed:                             0.89 mins
# KL between old and new distribution:      0.009979997
# Entropy:                                  0.96204937
# Surrogate loss:                           249.58183
#
# ********** Iteration 7 ************
# Rollout
# Made rollout
# Total number of episodes:                 707
# Average sum of rewards per episode:       -480.58653846153845
# Std of rewards per episode:               54.57221936552782
# Time elapsed:                             1.04 mins
# KL between old and new distribution:      0.009982644
# Entropy:                                  0.9448222
# Surrogate loss:                           242.92598
#
# ********** Iteration 8 ************
# Rollout
# Made rollout
# Total number of episodes:                 818
# Average sum of rewards per episode:       -449.92792792792795
# Std of rewards per episode:               68.13800406828204
# Time elapsed:                             1.18 mins
# KL between old and new distribution:      0.009997743
# Entropy:                                  0.92644435
# Surrogate loss:                           229.1494
#
# ********** Iteration 9 ************
# Rollout
# Made rollout
# Total number of episodes:                 934
# Average sum of rewards per episode:       -430.4913793103448
# Std of rewards per episode:               86.37822758974495
# Time elapsed:                             1.33 mins
# KL between old and new distribution:      0.009994477
# Entropy:                                  0.89589125
# Surrogate loss:                           222.96158
#
# ********** Iteration 10 ************
# Rollout
# Made rollout
# Total number of episodes:                 1071
# Average sum of rewards per episode:       -364.1021897810219
# Std of rewards per episode:               91.65265154566367
# Time elapsed:                             1.47 mins
# KL between old and new distribution:      0.009984305
# Entropy:                                  0.82260585
# Surrogate loss:                           192.77884
#
# ********** Iteration 11 ************
# Rollout
# Made rollout
# Total number of episodes:                 1213
# Average sum of rewards per episode:       -351.2464788732394
# Std of rewards per episode:               91.55296986126976
# Time elapsed:                             1.62 mins
# KL between old and new distribution:      0.009989511
# Entropy:                                  0.8339911
# Surrogate loss:                           186.75258
#
# ********** Iteration 12 ************
# Rollout
# Made rollout
# Total number of episodes:                 1351
# Average sum of rewards per episode:       -361.463768115942
# Std of rewards per episode:               92.9565239986804
# Time elapsed:                             1.76 mins
# KL between old and new distribution:      0.009988194
# Entropy:                                  0.81123084
# Surrogate loss:                           191.8316
#
# ********** Iteration 13 ************
# Rollout
# Made rollout
# Total number of episodes:                 1512
# Average sum of rewards per episode:       -309.62111801242236
# Std of rewards per episode:               83.26750606600339
# Time elapsed:                             1.91 mins
# KL between old and new distribution:      0.009994457
# Entropy:                                  0.78830826
# Surrogate loss:                           165.2748
#
# ********** Iteration 14 ************
# Rollout
# Made rollout
# Total number of episodes:                 1694
# Average sum of rewards per episode:       -273.7637362637363
# Std of rewards per episode:               79.13470365335344
# Time elapsed:                             2.05 mins
# KL between old and new distribution:      0.009969716
# Entropy:                                  0.76892334
# Surrogate loss:                           147.6007
#
# ********** Iteration 15 ************
# Rollout
# Made rollout
# Total number of episodes:                 1897
# Average sum of rewards per episode:       -245.32512315270935
# Std of rewards per episode:               66.21075998873089
# Time elapsed:                             2.19 mins
# KL between old and new distribution:      0.009992422
# Entropy:                                  0.7741302
# Surrogate loss:                           130.83586
#
# ********** Iteration 16 ************
# Rollout
# Made rollout
# Total number of episodes:                 2134
# Average sum of rewards per episode:       -209.9746835443038
# Std of rewards per episode:               57.245781747247044
# Time elapsed:                             2.33 mins
# KL between old and new distribution:      0.009987413
# Entropy:                                  0.76700115
# Surrogate loss:                           112.19125
#
# ********** Iteration 17 ************
# Rollout
# Made rollout
# Total number of episodes:                 2392
# Average sum of rewards per episode:       -192.80232558139534
# Std of rewards per episode:               53.60214181350193
# Time elapsed:                             2.48 mins
# KL between old and new distribution:      0.009998777
# Entropy:                                  0.7441094
# Surrogate loss:                           103.2616
#
# ********** Iteration 18 ************
# Rollout
# Made rollout
# Total number of episodes:                 2672
# Average sum of rewards per episode:       -177.58928571428572
# Std of rewards per episode:               63.37478565354405
# Time elapsed:                             2.62 mins
# KL between old and new distribution:      0.009979788
# Entropy:                                  0.74832094
# Surrogate loss:                           99.48332
#
# ********** Iteration 19 ************
# Rollout
# Made rollout
# Total number of episodes:                 2956
# Average sum of rewards per episode:       -175.07746478873239
# Std of rewards per episode:               65.43145794911918
# Time elapsed:                             2.77 mins
# KL between old and new distribution:      0.009977701
# Entropy:                                  0.7668199
# Surrogate loss:                           98.9795
#
# ********** Iteration 20 ************
# Rollout
# Made rollout
# Total number of episodes:                 3249
# Average sum of rewards per episode:       -169.6518771331058
# Std of rewards per episode:               61.26433777906269
# Time elapsed:                             2.91 mins
# KL between old and new distribution:      0.009975342
# Entropy:                                  0.7389905
# Surrogate loss:                           95.30472
#
# ********** Iteration 21 ************
# Rollout
# Made rollout
# Total number of episodes:                 3562
# Average sum of rewards per episode:       -158.75399361022363
# Std of rewards per episode:               54.96010919077527
# Time elapsed:                             3.06 mins
# KL between old and new distribution:      0.009994463
# Entropy:                                  0.72489315
# Surrogate loss:                           88.36387
#
# ********** Iteration 22 ************
# Rollout
# Made rollout
# Total number of episodes:                 3883
# Average sum of rewards per episode:       -154.78816199376948
# Std of rewards per episode:               59.89964595653556
# Time elapsed:                             3.20 mins
# KL between old and new distribution:      0.00999399
# Entropy:                                  0.73733515
# Surrogate loss:                           88.4253
#
# ********** Iteration 23 ************
# Rollout
# Made rollout
# Total number of episodes:                 4214
# Average sum of rewards per episode:       -150.06344410876133
# Std of rewards per episode:               39.01745165637359
# Time elapsed:                             3.34 mins
# KL between old and new distribution:      0.009995529
# Entropy:                                  0.7349643
# Surrogate loss:                           79.64606
#
# ********** Iteration 24 ************
# Rollout
# Made rollout
# Total number of episodes:                 4540
# Average sum of rewards per episode:       -152.38036809815952
# Std of rewards per episode:               42.76303784811684
# Time elapsed:                             3.49 mins
# KL between old and new distribution:      0.009969557
# Entropy:                                  0.7078419
# Surrogate loss:                           81.69586
#
# ********** Iteration 25 ************
# Rollout
# Made rollout
# Total number of episodes:                 4856
# Average sum of rewards per episode:       -157.24683544303798
# Std of rewards per episode:               62.440370208365444
# Time elapsed:                             3.63 mins
# KL between old and new distribution:      0.009971376
# Entropy:                                  0.6875488
# Surrogate loss:                           90.37245
#
# ********** Iteration 26 ************
# Rollout
# Made rollout
# Total number of episodes:                 5201
# Average sum of rewards per episode:       -143.93333333333334
# Std of rewards per episode:               45.3334654729532
# Time elapsed:                             3.78 mins
# KL between old and new distribution:      0.009988977
# Entropy:                                  0.67404795
# Surrogate loss:                           78.68492
#
# ********** Iteration 27 ************
# Rollout
# Made rollout
# Total number of episodes:                 5563
# Average sum of rewards per episode:       -137.12983425414365
# Std of rewards per episode:               46.679194845929395
# Time elapsed:                             3.92 mins
# KL between old and new distribution:      0.009975653
# Entropy:                                  0.65960217
# Surrogate loss:                           76.0512
#
# ********** Iteration 28 ************
# Rollout
# Made rollout
# Total number of episodes:                 5900
# Average sum of rewards per episode:       -147.37388724035608
# Std of rewards per episode:               48.65505332713362
# Time elapsed:                             4.07 mins
# KL between old and new distribution:      0.0099929385
# Entropy:                                  0.65813005
# Surrogate loss:                           81.22087
#
# ********** Iteration 29 ************
# Rollout
# Made rollout
# Total number of episodes:                 6233
# Average sum of rewards per episode:       -149.15315315315314
# Std of rewards per episode:               29.787394253677036
# Time elapsed:                             4.21 mins
# KL between old and new distribution:      0.009982661
# Entropy:                                  0.6638316
# Surrogate loss:                           77.05433
#
# ********** Iteration 30 ************
# Rollout
# Made rollout
# Total number of episodes:                 6595
# Average sum of rewards per episode:       -137.1243093922652
# Std of rewards per episode:               32.0574159492112
# Time elapsed:                             4.36 mins
# KL between old and new distribution:      0.0099974405
# Entropy:                                  0.6574953
# Surrogate loss:                           71.89002
#
# ********** Iteration 31 ************
# Rollout
# Made rollout
# Total number of episodes:                 6983
# Average sum of rewards per episode:       -127.86855670103093
# Std of rewards per episode:               28.63331526871649
# Time elapsed:                             4.50 mins
# KL between old and new distribution:      0.009998712
# Entropy:                                  0.6562042
# Surrogate loss:                           66.8186
#
# ********** Iteration 32 ************
# Rollout
# Made rollout
# Total number of episodes:                 7369
# Average sum of rewards per episode:       -128.53626943005182
# Std of rewards per episode:               24.700590091123072
# Time elapsed:                             4.65 mins
# KL between old and new distribution:      0.009983572
# Entropy:                                  0.65363204
# Surrogate loss:                           66.32937
#
# ********** Iteration 33 ************
# Rollout
# Made rollout
# Total number of episodes:                 7766
# Average sum of rewards per episode:       -124.9471032745592
# Std of rewards per episode:               28.989005523321214
# Time elapsed:                             4.79 mins
# KL between old and new distribution:      0.009968032
# Entropy:                                  0.6244926
# Surrogate loss:                           65.44079
#
# ********** Iteration 34 ************
# Rollout
# Made rollout
# Total number of episodes:                 8185
# Average sum of rewards per episode:       -118.33412887828162
# Std of rewards per episode:               29.878242255516525
# Time elapsed:                             4.93 mins
# KL between old and new distribution:      0.009989844
# Entropy:                                  0.6267839
# Surrogate loss:                           62.597576
#
# ********** Iteration 35 ************
# Rollout
# Made rollout
# Total number of episodes:                 8621
# Average sum of rewards per episode:       -113.68119266055047
# Std of rewards per episode:               21.08429378587579
# Time elapsed:                             5.08 mins
# KL between old and new distribution:      0.009990332
# Entropy:                                  0.6276478
# Surrogate loss:                           58.429234
#
# ********** Iteration 36 ************
# Rollout
# Made rollout
# Total number of episodes:                 9052
# Average sum of rewards per episode:       -115.01160092807424
# Std of rewards per episode:               21.008944178327322
# Time elapsed:                             5.22 mins
# KL between old and new distribution:      0.009982702
# Entropy:                                  0.6105898
# Surrogate loss:                           59.113605
#
# ********** Iteration 37 ************
# Rollout
# Made rollout
# Total number of episodes:                 9497
# Average sum of rewards per episode:       -111.36179775280898
# Std of rewards per episode:               25.42133716555718
# Time elapsed:                             5.37 mins
# KL between old and new distribution:      0.009998173
# Entropy:                                  0.5915884
# Surrogate loss:                           58.24467
#
# ********** Iteration 38 ************
# Rollout
# Made rollout
# Total number of episodes:                 9955
# Average sum of rewards per episode:       -108.17248908296943
# Std of rewards per episode:               19.841917461885867
# Time elapsed:                             5.51 mins
# KL between old and new distribution:      0.009978686
# Entropy:                                  0.561746
# Surrogate loss:                           55.594074
#
# ********** Iteration 39 ************
# Rollout
# Made rollout
# Total number of episodes:                 10422
# Average sum of rewards per episode:       -106.06852248394004
# Std of rewards per episode:               27.192383336541926
# Time elapsed:                             5.66 mins
# KL between old and new distribution:      0.009975606
# Entropy:                                  0.58218247
# Surrogate loss:                           56.24418
#
# ********** Iteration 40 ************
# Rollout
# Made rollout
# Total number of episodes:                 10885
# Average sum of rewards per episode:       -106.99352051835854
# Std of rewards per episode:               26.20054656914083
# Time elapsed:                             5.80 mins
# KL between old and new distribution:      0.009998291
# Entropy:                                  0.56681275
# Surrogate loss:                           56.397465
#
# ********** Iteration 41 ************
# Rollout
# Made rollout
# Total number of episodes:                 11355
# Average sum of rewards per episode:       -105.38510638297872
# Std of rewards per episode:               27.245897436427786
# Time elapsed:                             5.94 mins
# KL between old and new distribution:      0.009968656
# Entropy:                                  0.56406504
# Surrogate loss:                           55.849667
#
# ********** Iteration 42 ************
# Rollout
# Made rollout
# Total number of episodes:                 11823
# Average sum of rewards per episode:       -105.83974358974359
# Std of rewards per episode:               25.442115496945117
# Time elapsed:                             6.09 mins
# KL between old and new distribution:      0.009998154
# Entropy:                                  0.54230607
# Surrogate loss:                           55.67466
#
# ********** Iteration 43 ************
# Rollout
# Made rollout
# Total number of episodes:                 12292
# Average sum of rewards per episode:       -105.61194029850746
# Std of rewards per episode:               25.746565926407204
# Time elapsed:                             6.23 mins
# KL between old and new distribution:      0.009977542
# Entropy:                                  0.5199066
# Surrogate loss:                           55.621433
#
# ********** Iteration 44 ************
# Rollout
# Made rollout
# Total number of episodes:                 12787
# Average sum of rewards per episode:       -100.01212121212122
# Std of rewards per episode:               19.641428452688345
# Time elapsed:                             6.37 mins
# KL between old and new distribution:      0.009976509
# Entropy:                                  0.48999467
# Surrogate loss:                           51.61573
#
# ********** Iteration 45 ************
# Rollout
# Made rollout
# Total number of episodes:                 13280
# Average sum of rewards per episode:       -100.42190669371196
# Std of rewards per episode:               21.08325250818647
# Time elapsed:                             6.52 mins
# KL between old and new distribution:      0.009995661
# Entropy:                                  0.46846554
# Surrogate loss:                           52.1433
#
# ********** Iteration 46 ************
# Rollout
# Made rollout
# Total number of episodes:                 13795
# Average sum of rewards per episode:       -96.08932038834952
# Std of rewards per episode:               19.343792625293545
# Time elapsed:                             6.66 mins
# KL between old and new distribution:      0.00997438
# Entropy:                                  0.44630444
# Surrogate loss:                           49.7536
#
# ********** Iteration 47 ************
# Rollout
# Made rollout
# Total number of episodes:                 14306
# Average sum of rewards per episode:       -96.84931506849315
# Std of rewards per episode:               26.572111289031973
# Time elapsed:                             6.81 mins
# KL between old and new distribution:      0.009977453
# Entropy:                                  0.47868216
# Surrogate loss:                           51.71921
#
# ********** Iteration 48 ************
# Rollout
# Made rollout
# Total number of episodes:                 14811
# Average sum of rewards per episode:       -98.0118811881188
# Std of rewards per episode:               23.359435463512437
# Time elapsed:                             6.95 mins
# KL between old and new distribution:      0.009998755
# Entropy:                                  0.44052374
# Surrogate loss:                           51.53774
#
# ********** Iteration 49 ************
# Rollout
# Made rollout
# Total number of episodes:                 15326
# Average sum of rewards per episode:       -96.08932038834952
# Std of rewards per episode:               22.62689744281444
# Time elapsed:                             7.09 mins
# KL between old and new distribution:      0.009987367
# Entropy:                                  0.41130546
# Surrogate loss:                           50.4626
#
# ********** Iteration 50 ************
# Rollout
# Made rollout
# Total number of episodes:                 15854
# Average sum of rewards per episode:       -93.69886363636364
# Std of rewards per episode:               20.24345757192317
# Time elapsed:                             7.24 mins
# KL between old and new distribution:      0.009995898
# Entropy:                                  0.38769922
# Surrogate loss:                           48.80349
#
# ********** Iteration 51 ************
# Rollout
# Made rollout
# Total number of episodes:                 16388
# Average sum of rewards per episode:       -92.63483146067416
# Std of rewards per episode:               20.254365236015584
# Time elapsed:                             7.39 mins
# KL between old and new distribution:      0.0099714575
# Entropy:                                  0.3948533
# Surrogate loss:                           48.31525
#
# ********** Iteration 52 ************
# Rollout
# Made rollout
# Total number of episodes:                 16920
# Average sum of rewards per episode:       -92.98684210526316
# Std of rewards per episode:               19.975403479355286
# Time elapsed:                             7.53 mins
# KL between old and new distribution:      0.0099739935
# Entropy:                                  0.36350086
# Surrogate loss:                           48.45527
#
# ********** Iteration 53 ************
# Rollout
# Made rollout
# Total number of episodes:                 17463
# Average sum of rewards per episode:       -91.0828729281768
# Std of rewards per episode:               19.984582949126544
# Time elapsed:                             7.67 mins
# KL between old and new distribution:      0.009982914
# Entropy:                                  0.3438379
# Surrogate loss:                           47.49681
#
# ********** Iteration 54 ************
# Rollout
# Made rollout
# Total number of episodes:                 18021
# Average sum of rewards per episode:       -88.60752688172043
# Std of rewards per episode:               16.717720106769157
# Time elapsed:                             7.82 mins
# KL between old and new distribution:      0.0099943215
# Entropy:                                  0.31420234
# Surrogate loss:                           45.685005
#
# ********** Iteration 55 ************
# Rollout
# Made rollout
# Total number of episodes:                 18583
# Average sum of rewards per episode:       -87.96975088967972
# Std of rewards per episode:               19.783997530856432
# Time elapsed:                             7.96 mins
# KL between old and new distribution:      0.009990913
# Entropy:                                  0.32406175
# Surrogate loss:                           45.94456
#
# ********** Iteration 56 ************
# Rollout
# Made rollout
# Total number of episodes:                 19143
# Average sum of rewards per episode:       -88.2875
# Std of rewards per episode:               17.43542742419255
# Time elapsed:                             8.10 mins
# KL between old and new distribution:      0.009994008
# Entropy:                                  0.28835607
# Surrogate loss:                           45.70354
#
# ********** Iteration 57 ************
# Rollout
# Made rollout
# Total number of episodes:                 19716
# Average sum of rewards per episode:       -86.26178010471205
# Std of rewards per episode:               18.966615889430454
# Time elapsed:                             8.25 mins
# KL between old and new distribution:      0.009977646
# Entropy:                                  0.2733299
# Surrogate loss:                           45.0057
#
# ********** Iteration 58 ************
# Rollout
# Made rollout
# Total number of episodes:                 20265
# Average sum of rewards per episode:       -90.07650273224044
# Std of rewards per episode:               19.351827732417092
# Time elapsed:                             8.39 mins
# KL between old and new distribution:      0.009998468
# Entropy:                                  0.26968434
# Surrogate loss:                           46.89745
#
# ********** Iteration 59 ************
# Rollout
# Made rollout
# Total number of episodes:                 20814
# Average sum of rewards per episode:       -90.07650273224044
# Std of rewards per episode:               19.60979955039421
# Time elapsed:                             8.54 mins
# KL between old and new distribution:      0.009991404
# Entropy:                                  0.2826766
# Surrogate loss:                           46.94957
#
# ********** Iteration 60 ************
# Rollout
# Made rollout
# Total number of episodes:                 21346
# Average sum of rewards per episode:       -92.98684210526316
# Std of rewards per episode:               25.097363335989666
# Time elapsed:                             8.68 mins
# KL between old and new distribution:      0.009968884
# Entropy:                                  0.27680472
# Surrogate loss:                           49.5915
#
# ********** Iteration 61 ************
# Rollout
# Made rollout
# Total number of episodes:                 21899
# Average sum of rewards per episode:       -89.41772151898734
# Std of rewards per episode:               19.289762781172634
# Time elapsed:                             8.82 mins
# KL between old and new distribution:      0.009978534
# Entropy:                                  0.27922437
# Surrogate loss:                           46.59256
#
# ********** Iteration 62 ************
# Rollout
# Made rollout
# Total number of episodes:                 22459
# Average sum of rewards per episode:       -88.2875
# Std of rewards per episode:               19.722209765533737
# Time elapsed:                             8.97 mins
# KL between old and new distribution:      0.009971223
# Entropy:                                  0.28487226
# Surrogate loss:                           46.17318
#
# ********** Iteration 63 ************
# Rollout
# Made rollout
# Total number of episodes:                 23029
# Average sum of rewards per episode:       -86.72105263157894
# Std of rewards per episode:               20.35960256085139
# Time elapsed:                             9.11 mins
# KL between old and new distribution:      0.009974564
# Entropy:                                  0.27556384
# Surrogate loss:                           45.498
#
# ********** Iteration 64 ************
# Rollout
# Made rollout
# Total number of episodes:                 23581
# Average sum of rewards per episode:       -89.58152173913044
# Std of rewards per episode:               21.015881310321664
# Time elapsed:                             9.26 mins
# KL between old and new distribution:      0.009995254
# Entropy:                                  0.24999925
# Surrogate loss:                           47.037315
#
# ********** Iteration 65 ************
# Rollout
# Made rollout
# Total number of episodes:                 24137
# Average sum of rewards per episode:       -88.92985611510791
# Std of rewards per episode:               20.036668920210918
# Time elapsed:                             9.41 mins
# KL between old and new distribution:      0.009984053
# Entropy:                                  0.22153273
# Surrogate loss:                           46.501606
#
# ********** Iteration 66 ************
# Rollout
# Made rollout
# Total number of episodes:                 24719
# Average sum of rewards per episode:       -84.91237113402062
# Std of rewards per episode:               17.027798725298286
# Time elapsed:                             9.55 mins
# KL between old and new distribution:      0.00997729
# Entropy:                                  0.21660617
# Surrogate loss:                           43.99866
#
# ********** Iteration 67 ************
# Rollout
# Made rollout
# Total number of episodes:                 25288
# Average sum of rewards per episode:       -86.87521968365553
# Std of rewards per episode:               24.164860710162305
# Time elapsed:                             9.69 mins
# KL between old and new distribution:      0.009983588
# Entropy:                                  0.20300618
# Surrogate loss:                           46.584644
#
# ********** Iteration 68 ************
# Rollout
# Made rollout
# Total number of episodes:                 25868
# Average sum of rewards per episode:       -85.20862068965518
# Std of rewards per episode:               18.86283322854358
# Time elapsed:                             9.84 mins
# KL between old and new distribution:      0.00998038
# Entropy:                                  0.19426616
# Surrogate loss:                           44.51825
#
# ********** Iteration 69 ************
# Rollout
# Made rollout
# Total number of episodes:                 26451
# Average sum of rewards per episode:       -84.76500857632934
# Std of rewards per episode:               20.871361544437462
# Time elapsed:                             9.98 mins
# KL between old and new distribution:      0.009992829
# Entropy:                                  0.18630895
# Surrogate loss:                           44.7794
#
# ********** Iteration 70 ************
# Rollout
# Made rollout
# Total number of episodes:                 27017
# Average sum of rewards per episode:       -87.34098939929329
# Std of rewards per episode:               26.958061560876907
# Time elapsed:                             10.13 mins
# KL between old and new distribution:      0.0099697225
# Entropy:                                  0.1803259
# Surrogate loss:                           47.53725
#
# ********** Iteration 71 ************
# Rollout
# Made rollout
# Total number of episodes:                 27601
# Average sum of rewards per episode:       -84.6181506849315
# Std of rewards per episode:               17.557530074969495
# Time elapsed:                             10.28 mins
# KL between old and new distribution:      0.009988528
# Entropy:                                  0.17896715
# Surrogate loss:                           43.94219
#
# ********** Iteration 72 ************
# Rollout
# Made rollout
# Total number of episodes:                 28175
# Average sum of rewards per episode:       -86.10975609756098
# Std of rewards per episode:               26.326484239532995
# Time elapsed:                             10.42 mins
# KL between old and new distribution:      0.00998887
# Entropy:                                  0.17410761
# Surrogate loss:                           46.769985
#
# ********** Iteration 73 ************
# Rollout
# Made rollout
# Total number of episodes:                 28761
# Average sum of rewards per episode:       -84.3259385665529
# Std of rewards per episode:               19.54118542651287
# Time elapsed:                             10.56 mins
# KL between old and new distribution:      0.009990107
# Entropy:                                  0.1639643
# Surrogate loss:                           44.22223
#
# ********** Iteration 74 ************
# Rollout
# Made rollout
# Total number of episodes:                 29333
# Average sum of rewards per episode:       -86.41608391608392
# Std of rewards per episode:               35.51545935498731
# Time elapsed:                             10.71 mins
# KL between old and new distribution:      0.009978374
# Entropy:                                  0.18433648
# Surrogate loss:                           50.060505
#
# ********** Iteration 75 ************
# Rollout
# Made rollout
# Total number of episodes:                 29913
# Average sum of rewards per episode:       -85.21034482758621
# Std of rewards per episode:               27.963841737298548
# Time elapsed:                             10.86 mins
# KL between old and new distribution:      0.009988809
# Entropy:                                  0.17906569
# Surrogate loss:                           46.8459
#
# ********** Iteration 76 ************
# Rollout
# Made rollout
# Total number of episodes:                 30485
# Average sum of rewards per episode:       -86.41608391608392
# Std of rewards per episode:               31.313633730238966
# Time elapsed:                             11.00 mins
# KL between old and new distribution:      0.009989675
# Entropy:                                  0.1790266
# Surrogate loss:                           48.675156
#
# ********** Iteration 77 ************
# Rollout
# Made rollout
# Total number of episodes:                 31072
# Average sum of rewards per episode:       -84.18057921635435
# Std of rewards per episode:               20.203178296820738
# Time elapsed:                             11.14 mins
# KL between old and new distribution:      0.009991159
# Entropy:                                  0.172908
# Surrogate loss:                           44.27086
#
# ********** Iteration 78 ************
# Rollout
# Made rollout
# Total number of episodes:                 31651
# Average sum of rewards per episode:       -85.36096718480138
# Std of rewards per episode:               33.69090317248125
# Time elapsed:                             11.29 mins
# KL between old and new distribution:      0.009993631
# Entropy:                                  0.16863254
# Surrogate loss:                           48.9701
#
# ********** Iteration 79 ************
# Rollout
# Made rollout
# Total number of episodes:                 32224
# Average sum of rewards per episode:       -86.26178010471205
# Std of rewards per episode:               28.63334845860061
# Time elapsed:                             11.43 mins
# KL between old and new distribution:      0.009991675
# Entropy:                                  0.16655663
# Surrogate loss:                           47.569466
#
# ********** Iteration 80 ************
# Rollout
# Made rollout
# Total number of episodes:                 32784
# Average sum of rewards per episode:       -88.29464285714286
# Std of rewards per episode:               46.71131676754749
# Time elapsed:                             11.58 mins
# KL between old and new distribution:      0.009979497
# Entropy:                                  0.18643199
# Surrogate loss:                           55.983833
#
# ********** Iteration 81 ************
# Rollout
# Made rollout
# Total number of episodes:                 33373
# Average sum of rewards per episode:       -83.893039049236
# Std of rewards per episode:               28.666582280777988
# Time elapsed:                             11.72 mins
# KL between old and new distribution:      0.009987108
# Entropy:                                  0.16580021
# Surrogate loss:                           46.48149
#
# ********** Iteration 82 ************
# Rollout
# Made rollout
# Total number of episodes:                 33967
# Average sum of rewards per episode:       -83.17676767676768
# Std of rewards per episode:               20.522568647601616
# Time elapsed:                             11.87 mins
# KL between old and new distribution:      0.0099888295
# Entropy:                                  0.17010254
# Surrogate loss:                           43.93735
#
# ********** Iteration 83 ************
# Rollout
# Made rollout
# Total number of episodes:                 34555
# Average sum of rewards per episode:       -84.03571428571429
# Std of rewards per episode:               21.916129943506913
# Time elapsed:                             12.01 mins
# KL between old and new distribution:      0.009965895
# Entropy:                                  0.1679798
# Surrogate loss:                           44.647884
#
# ********** Iteration 84 ************
# Rollout
# Made rollout
# Total number of episodes:                 35153
# Average sum of rewards per episode:       -82.61371237458194
# Std of rewards per episode:               20.66720567870996
# Time elapsed:                             12.16 mins
# KL between old and new distribution:      0.009979361
# Entropy:                                  0.1663227
# Surrogate loss:                           43.6988
#
# ********** Iteration 85 ************
# Rollout
# Made rollout
# Total number of episodes:                 35743
# Average sum of rewards per episode:       -83.74745762711865
# Std of rewards per episode:               18.858409587778286
# Time elapsed:                             12.30 mins
# KL between old and new distribution:      0.009983184
# Entropy:                                  0.13975693
# Surrogate loss:                           43.827576
#
# ********** Iteration 86 ************
# Rollout
# Made rollout
# Total number of episodes:                 36328
# Average sum of rewards per episode:       -84.47350427350428
# Std of rewards per episode:               30.779664707643242
# Time elapsed:                             12.45 mins
# KL between old and new distribution:      0.009973207
# Entropy:                                  0.14071953
# Surrogate loss:                           47.449783
#
# ********** Iteration 87 ************
# Rollout
# Made rollout
# Total number of episodes:                 36923
# Average sum of rewards per episode:       -83.03529411764706
# Std of rewards per episode:               24.814209091015865
# Time elapsed:                             12.60 mins
# KL between old and new distribution:      0.009977767
# Entropy:                                  0.13179903
# Surrogate loss:                           45.03785
#
# ********** Iteration 88 ************
# Rollout
# Made rollout
# Total number of episodes:                 37503
# Average sum of rewards per episode:       -85.21206896551725
# Std of rewards per episode:               37.80309500915376
# Time elapsed:                             12.74 mins
# KL between old and new distribution:      0.0099905655
# Entropy:                                  0.13424763
# Surrogate loss:                           50.65942
#
# ********** Iteration 89 ************
# Rollout
# Made rollout
# Total number of episodes:                 38094
# Average sum of rewards per episode:       -83.60575296108291
# Std of rewards per episode:               30.37139373535521
# Time elapsed:                             12.89 mins
# KL between old and new distribution:      0.009968168
# Entropy:                                  0.14369522
# Surrogate loss:                           47.072655
#
# ********** Iteration 90 ************
# Rollout
# Made rollout
# Total number of episodes:                 38695
# Average sum of rewards per episode:       -82.19800332778702
# Std of rewards per episode:               23.897014120322176
# Time elapsed:                             13.03 mins
# KL between old and new distribution:      0.009998079
# Entropy:                                  0.14196722
# Surrogate loss:                           44.29779
#
# ********** Iteration 91 ************
# Rollout
# Made rollout
# Total number of episodes:                 39279
# Average sum of rewards per episode:       -84.62328767123287
# Std of rewards per episode:               37.763891649019556
# Time elapsed:                             13.18 mins
# KL between old and new distribution:      0.009990111
# Entropy:                                  0.14857608
# Surrogate loss:                           50.37372
#
# ********** Iteration 92 ************
# Rollout
# Made rollout
# Total number of episodes:                 39860
# Average sum of rewards per episode:       -85.06368330464716
# Std of rewards per episode:               32.63480301525699
# Time elapsed:                             13.32 mins
# KL between old and new distribution:      0.00998111
# Entropy:                                  0.15004988
# Surrogate loss:                           48.4291
#
# ********** Iteration 93 ************
# Rollout
# Made rollout
# Total number of episodes:                 40438
# Average sum of rewards per episode:       -85.5121107266436
# Std of rewards per episode:               38.387309015724306
# Time elapsed:                             13.46 mins
# KL between old and new distribution:      0.009994294
# Entropy:                                  0.15028197
# Surrogate loss:                           50.86604
#
# ********** Iteration 94 ************
# Rollout
# Made rollout
# Total number of episodes:                 41020
# Average sum of rewards per episode:       -84.91408934707904
# Std of rewards per episode:               29.610463706947762
# Time elapsed:                             13.61 mins
# KL between old and new distribution:      0.009991723
# Entropy:                                  0.14487435
# Surrogate loss:                           47.27296
#
# ********** Iteration 95 ************
# Rollout
# Made rollout
# Total number of episodes:                 41599
# Average sum of rewards per episode:       -85.36096718480138
# Std of rewards per episode:               32.00516899795828
# Time elapsed:                             13.75 mins
# KL between old and new distribution:      0.009974837
# Entropy:                                  0.13959521
# Surrogate loss:                           48.34801
#
# ********** Iteration 96 ************
# Rollout
# Made rollout
# Total number of episodes:                 42161
# Average sum of rewards per episode:       -87.98220640569394
# Std of rewards per episode:               52.20647179826345
# Time elapsed:                             13.89 mins
# KL between old and new distribution:      0.009975554
# Entropy:                                  0.15935048
# Surrogate loss:                           58.975487
#
# ********** Iteration 97 ************
# Rollout
# Made rollout
# Total number of episodes:                 42754
# Average sum of rewards per episode:       -83.3220910623946
# Std of rewards per episode:               33.7228931955087
# Time elapsed:                             14.04 mins
# KL between old and new distribution:      0.009992404
# Entropy:                                  0.14342603
# Surrogate loss:                           48.121925
#
# ********** Iteration 98 ************
# Rollout
# Made rollout
# Total number of episodes:                 43311
# Average sum of rewards per episode:       -88.78276481149013
# Std of rewards per episode:               55.0462301959281
# Time elapsed:                             14.19 mins
# KL between old and new distribution:      0.009964215
# Entropy:                                  0.15399545
# Surrogate loss:                           60.96957
#
# ********** Iteration 99 ************
# Rollout
# Made rollout
# Total number of episodes:                 43902
# Average sum of rewards per episode:       -83.60913705583756
# Std of rewards per episode:               36.225013809273584
# Time elapsed:                             14.33 mins
# KL between old and new distribution:      0.009970106
# Entropy:                                  0.13652167
# Surrogate loss:                           49.26336
#
# ********** Iteration 100 ************
# Rollout
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 15
#      11     print("\n********** Iteration %i ************" % i)
#      12
#      13     # Generating paths.
#      14     print("Rollout")
# ---> 15     paths = rollout(env, agent)
#      16     print("Made rollout")
#      17
#      18     # Updating policy.
#
# Cell In[25], line 20, in rollout(env, agent, max_pathlength, n_timesteps)
#      16             action, policy = agent.act(obervation)
#      17             obervations.append(obervation)
#      18             actions.append(action)
#      19             action_probs.append(policy)
# ---> 20             obervation, reward, terminated, truncated, _ = env.step(action)
#      21             rewards.append(reward)
#      22             total_timesteps += 1
#      23             if terminated or truncated or total_timesteps >= n_timesteps:
#
# File ~/Desktop/code/.venv/lib/python3.12/site-packages/gymnasium/wrappers/common.py:124, in TimeLimit.step(self, action)
#     111 def step(
#     112     self, action: ActType
#     113 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     114     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#     115
#     116     Args:
#    (...)    122
#     123     """
# --> 124     observation, reward, terminated, truncated, info = self.env.step(action)
#     125     self._elapsed_steps += 1
#     127     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/Desktop/code/.venv/lib/python3.12/site-packages/gymnasium/wrappers/common.py:392, in OrderEnforcing.step(self, action)
#     390 if not self._has_reset:
#     391     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 392 return super().step(action)
#
# File ~/Desktop/code/.venv/lib/python3.12/site-packages/gymnasium/core.py:327, in Wrapper.step(self, action)
#     323 def step(
#     324     self, action: WrapperActType
#     325 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327     return self.env.step(action)
#
# File ~/Desktop/code/.venv/lib/python3.12/site-packages/gymnasium/wrappers/common.py:284, in PassiveEnvChecker.step(self, action)
#     282     return env_step_passive_checker(self.env, action)
#     283 else:
# --> 284     return self.env.step(action)
#
# File ~/Desktop/code/.venv/lib/python3.12/site-packages/gymnasium/envs/classic_control/acrobot.py:217, in AcrobotEnv.step(self, a)
#     213 # Now, augment the state with our force action so it can be passed to
#     214 # _dsdt
#     215 s_augmented = np.append(s, torque)
# --> 217 ns = rk4(self._dsdt, s_augmented, [0, self.dt])
#     219 ns[0] = wrap(ns[0], -pi, pi)
#     220 ns[1] = wrap(ns[1], -pi, pi)
#
# File ~/Desktop/code/.venv/lib/python3.12/site-packages/gymnasium/envs/classic_control/acrobot.py:458, in rk4(derivs, y0, t)
#     456 k1 = np.asarray(derivs(y0))
#     457 k2 = np.asarray(derivs(y0 + dt2 * k1))
# --> 458 k3 = np.asarray(derivs(y0 + dt2 * k2))
#     459 k4 = np.asarray(derivs(y0 + dt * k3))
#     460 yout[i + 1] = y0 + dt / 6.0 * (k1 + 2 * k2 + 2 * k3 + k4)
#
# File ~/Desktop/code/.venv/lib/python3.12/site-packages/gymnasium/envs/classic_control/acrobot.py:263, in AcrobotEnv._dsdt(self, s_augmented)
#     260 d2 = m2 * (lc2**2 + l1 * lc2 * cos(theta2)) + I2
#     261 phi2 = m2 * lc2 * g * cos(theta1 + theta2 - pi / 2.0)
#     262 phi1 = (
# --> 263     -m2 * l1 * lc2 * dtheta2**2 * sin(theta2)
#     264     - 2 * m2 * l1 * lc2 * dtheta2 * dtheta1 * sin(theta2)
#     265     + (m1 * lc1 + m2 * l1) * g * cos(theta1 - pi / 2)
#     266     + phi2
#     267 )
#     268 if self.book_or_nips == "nips":
#     269     # the following line is consistent with the description in the
#     270     # paper
#     271     ddtheta2 = (a + d2 / d1 * phi1 - phi2) / (m2 * lc2**2 + I2 - d2**2 / d1)
#
# KeyboardInterrupt:

# %%
def record_one_game(
    agent,
    env_name: str = "Acrobot-v1",
    video_dir: str = "./videos_trpo",
    name_prefix: str = "trpo-acrobot",
    sample: bool = False,
    max_steps: Optional[int] = None,
) -> tuple[Path, float]:
    os.makedirs(video_dir, exist_ok=True)

    env = gym.wrappers.RecordVideo(
        gym.make(env_name, render_mode="rgb_array"),
        video_folder=video_dir,
        episode_trigger=lambda ep_id: True,
        name_prefix=name_prefix,
    )

    obs, _ = env.reset()
    total_reward = 0.0
    done = False
    step = 0
    while not done:
        action, _ = agent.act(obs, sample=sample)
        obs, reward, terminated, truncated, _ = env.step(action)
        total_reward += float(reward)
        step += 1
        if max_steps is not None and step >= max_steps:
            break
        done = terminated or truncated
    env.close()

    video_paths = sorted(Path(video_dir).glob("*.mp4"))
    if not video_paths:
        raise RuntimeError(f"No video recorded in {video_dir!r}")
    return video_paths[-1], total_reward


def video_to_html(video_path: Path | str, width: int = 480) -> str:
    """Return an HTML snippet that embeds the given mp4 inline (base64)."""
    video_path = Path(video_path)
    data_url = "data:video/mp4;base64," + b64encode(video_path.read_bytes()).decode()
    return (
        f'<video width="{width}" controls>'
        f'<source src="{data_url}" type="video/mp4"></video>'
    )

# %%
record_one_game(agent)
# Out:
# /Users/mihansgambit/Desktop/code/.venv/lib/python3.12/site-packages/gymnasium/wrappers/rendering.py:292: UserWarning: WARN: Overwriting existing videos at /Users/mihansgambit/Desktop/code/Practical_RL/week09_policy_II/videos_trpo folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# (PosixPath('videos_trpo/trpo-acrobot-episode-0.mp4'), -64.0)

# %% [markdown]
# # Homework option I: better sampling (10+pts)
#
# In this section, you're invited to implement a better rollout strategy called _vine_.
#
# ![img](https://s17.postimg.cc/i90chxgvj/vine.png)
#
# In most gym environments, you can actually backtrack by using states. You can find a wrapper that saves/loads states in [the MCTS seminar](https://github.com/yandexdataschool/Practical_RL/blob/master/week10_planning/seminar_MCTS.ipynb).
#
# You can read more about TRPO in the [original paper](https://arxiv.org/abs/1502.05477) in section 5.2.
#
# The goal here is to implement such rollout policy (we recommend using tree data structure like in the seminar above).
# Then you can assign cumulative rewards similar to `get_cumulative_rewards`, but for a tree.
#
# __bonus task__ - parallelize samples using multiple cores

# %% [markdown]
# # Homework option II (10+pts)
#
# Let's use TRPO to train evil robots! (pick any of two)
# * [MuJoCo robots](https://gymnasium.farama.org/environments/mujoco/#mujoco)
# * [Box2d robot](https://gymnasium.farama.org/environments/box2d/bipedal_walker/)
#
# The catch here is that those environments have continuous action spaces.
#
# Luckily, TRPO is a policy gradient method, so it's gonna work for any parametric $\pi_\theta(a|s)$. We recommend starting with gaussian policy:
#
# $$\pi_\theta(a|s) = N(\mu_\theta(s),\sigma^2_\theta(s)) = {1 \over \sqrt { 2 \pi {\sigma^2}_\theta(s) } } e^{ (a -
# \mu_\theta(s))^2 \over 2 {\sigma^2}_\theta(s) } $$
#
# In the $\sqrt { 2 \pi {\sigma^2}_\theta(s) }$ clause, $\pi$ means ~3.1415926, not agent's policy.
#
# This essentially means that you will need two output layers:
# * $\mu_\theta(s)$, a dense layer with linear activation
# * ${\sigma^2}_\theta(s)$, a dense layer with activation tf.exp (to make it positive; like rho from bandits)
#
# For multidimensional actions, you can use a fully factorized gaussian (basically a vector of gaussians).
#
# __Bonus task__: compare the performance of the continuous action space method to action space discretization.
