# %% [markdown]
# ### Markov decision process
#
# This week's methods are all built to solve __M__arkov __D__ecision __P__rocesses. In the broadest sense, an MDP is defined by how it changes states and how rewards are computed.
#
# State transition is defined by $P(s' |s,a)$ - how likely are you to end at state $s'$ if you take action $a$ from state $s$. Now there's more than one way to define rewards, but we'll use $r(s,a,s')$ function for convenience.
#
# _This notebook is inspired by the awesome_ [CS294](https://github.com/berkeleydeeprlcourse/homework/blob/36a0b58261acde756abd55306fbe63df226bf62b/hw2/HW2.ipynb) _by Berkeley_

# %% [markdown]
# For starters, let's define a simple MDP from this picture:
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/a/ad/Markov_Decision_Process.svg" width="400px" alt="Diagram by Waldoalvarez via Wikimedia Commons, CC BY-SA 4.0"/>

# %%
# %pip install torch
# %pip install "gymnasium[all]"
# %pip install numpy
# %pip install gym
# Out:
# Collecting gymnasium[all]
#   Using cached gymnasium-1.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting numpy>=1.21.0 (from gymnasium[all])
#   Downloading numpy-2.4.4-cp312-cp312-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Collecting cloudpickle>=1.2.0 (from gymnasium[all])
#   Using cached cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/mihansgambit/Desktop/code/.venv/lib/python3.12/site-packages (from gymnasium[all]) (4.15.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium[all])
#   Using cached farama_notifications-0.0.6-py3-none-any.whl.metadata (729 bytes)
# Collecting ale_py>=0.9 (from gymnasium[all])
#   Downloading ale_py-0.11.2-cp312-cp312-macosx_13_0_arm64.whl.metadata (9.0 kB)
# Collecting box2d-py==2.3.5 (from gymnasium[all])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pygame-ce>=2.1.3 (from gymnasium[all])
#   Downloading pygame_ce-2.5.7-cp312-cp312-macosx_10_13_universal2.whl.metadata (11 kB)
# Collecting swig==4.* (from gymnasium[all])
#   Downloading swig-4.4.1-py3-none-macosx_10_9_universal2.whl.metadata (3.5 kB)
# Collecting mujoco>=2.1.5 (from gymnasium[all])
#   Downloading mujoco-3.8.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (42 kB)
# Collecting imageio>=2.14.1 (from gymnasium[all])
#   Downloading imageio-2.37.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: packaging>=23.0 in /Users/mihansgambit/Desktop/code/.venv/lib/python3.12/site-packages (from gymnasium[all]) (26.2)
# Collecting jax>=0.4.16 (from gymnasium[all])
#   Downloading jax-0.10.0-py3-none-any.whl.metadata (13 kB)
# Collecting jaxlib>=0.4.16 (from gymnasium[all])
#   Downloading jaxlib-0.10.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (1.3 kB)
# Collecting flax>=0.5.0 (from gymnasium[all])
#   Downloading flax-0.12.7-py3-none-any.whl.metadata (11 kB)
# Collecting array-api-compat>=1.11.0 (from gymnasium[all])
#   Downloading array_api_compat-1.14.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: torch>=1.13.0 in /Users/mihansgambit/Desktop/code/.venv/lib/python3.12/site-packages (from gymnasium[all]) (2.11.0)
# Collecting opencv-python>=3.0 (from gymnasium[all])
#   Downloading opencv_python-4.13.0.92-cp37-abi3-macosx_13_0_arm64.whl.metadata (19 kB)
# Collecting matplotlib>=3.0 (from gymnasium[all])
#   Downloading matplotlib-3.10.9-cp312-cp312-macosx_11_0_arm64.whl.metadata (52 kB)
# Collecting moviepy>=1.0.0 (from gymnasium[all])
#   Downloading moviepy-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting msgpack (from flax>=0.5.0->gymnasium[all])
#   Downloading msgpack-1.1.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Collecting optax (from flax>=0.5.0->gymnasium[all])
#   Downloading optax-0.2.8-py3-none-any.whl.metadata (7.9 kB)
# Collecting orbax-checkpoint (from flax>=0.5.0->gymnasium[all])
#   Downloading orbax_checkpoint-0.11.36-py3-none-any.whl.metadata (2.7 kB)
# Collecting tensorstore (from flax>=0.5.0->gymnasium[all])
#   Downloading tensorstore-0.1.82-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.3 kB)
# Collecting rich>=11.1 (from flax>=0.5.0->gymnasium[all])
#   Using cached rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting PyYAML>=5.4.1 (from flax>=0.5.0->gymnasium[all])
#   Downloading pyyaml-6.0.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.4 kB)
# Collecting treescope>=0.1.7 (from flax>=0.5.0->gymnasium[all])
#   Downloading treescope-0.1.10-py3-none-any.whl.metadata (6.6 kB)
# Collecting pillow>=8.3.2 (from imageio>=2.14.1->gymnasium[all])
#   Downloading pillow-12.2.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting ml_dtypes>=0.5.0 (from jax>=0.4.16->gymnasium[all])
#   Using cached ml_dtypes-0.5.4-cp312-cp312-macosx_10_13_universal2.whl.metadata (8.9 kB)
# Collecting opt_einsum (from jax>=0.4.16->gymnasium[all])
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting scipy>=1.14 (from jax>=0.4.16->gymnasium[all])
#   Using cached scipy-1.17.1-cp312-cp312-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.0->gymnasium[all])
#   Downloading contourpy-1.3.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.0->gymnasium[all])
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.0->gymnasium[all])
#   Downloading fonttools-4.62.1-cp312-cp312-macosx_10_13_universal2.whl.metadata (117 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.0->gymnasium[all])
#   Downloading kiwisolver-1.5.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.1 kB)
# Collecting pyparsing>=3 (from matplotlib>=3.0->gymnasium[all])
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mihansgambit/Desktop/code/.venv/lib/python3.12/site-packages (from matplotlib>=3.0->gymnasium[all]) (2.9.0.post0)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in /Users/mihansgambit/Desktop/code/.venv/lib/python3.12/site-packages (from moviepy>=1.0.0->gymnasium[all]) (5.2.1)
# Collecting imageio_ffmpeg>=0.2.0 (from moviepy>=1.0.0->gymnasium[all])
#   Downloading imageio_ffmpeg-0.6.0-py3-none-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Collecting proglog<=1.0.0 (from moviepy>=1.0.0->gymnasium[all])
#   Downloading proglog-0.1.12-py3-none-any.whl.metadata (794 bytes)
# Collecting python-dotenv>=0.10 (from moviepy>=1.0.0->gymnasium[all])
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting pillow>=8.3.2 (from imageio>=2.14.1->gymnasium[all])
#   Downloading pillow-11.3.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.0 kB)
# Collecting tqdm (from proglog<=1.0.0->moviepy>=1.0.0->gymnasium[all])
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting absl-py (from mujoco>=2.1.5->gymnasium[all])
#   Using cached absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting etils[epath] (from mujoco>=2.1.5->gymnasium[all])
#   Downloading etils-1.14.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting glfw (from mujoco>=2.1.5->gymnasium[all])
#   Downloading glfw-2.10.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.py39.py310.py311.py312.py313.py314-none-macosx_11_0_arm64.whl.metadata (5.4 kB)
# Collecting pyopengl (from mujoco>=2.1.5->gymnasium[all])
#   Downloading pyopengl-3.1.10-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: six>=1.5 in /Users/mihansgambit/Desktop/code/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.0->gymnasium[all]) (1.17.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=11.1->flax>=0.5.0->gymnasium[all])
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/mihansgambit/Desktop/code/.venv/lib/python3.12/site-packages (from rich>=11.1->flax>=0.5.0->gymnasium[all]) (2.20.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.5.0->gymnasium[all])
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: filelock in /Users/mihansgambit/Desktop/code/.venv/lib/python3.12/site-packages (from torch>=1.13.0->gymnasium[all]) (3.29.0)
# Requirement already satisfied: setuptools<82 in /Users/mihansgambit/Desktop/code/.venv/lib/python3.12/site-packages (from torch>=1.13.0->gymnasium[all]) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/mihansgambit/Desktop/code/.venv/lib/python3.12/site-packages (from torch>=1.13.0->gymnasium[all]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/mihansgambit/Desktop/code/.venv/lib/python3.12/site-packages (from torch>=1.13.0->gymnasium[all]) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/mihansgambit/Desktop/code/.venv/lib/python3.12/site-packages (from torch>=1.13.0->gymnasium[all]) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/mihansgambit/Desktop/code/.venv/lib/python3.12/site-packages (from torch>=1.13.0->gymnasium[all]) (2026.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/mihansgambit/Desktop/code/.venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.13.0->gymnasium[all]) (1.3.0)
# Collecting zipp (from etils[epath]->mujoco>=2.1.5->gymnasium[all])
#   Downloading zipp-3.23.1-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/mihansgambit/Desktop/code/.venv/lib/python3.12/site-packages (from jinja2->torch>=1.13.0->gymnasium[all]) (3.0.3)
# Collecting aiofiles (from orbax-checkpoint->flax>=0.5.0->gymnasium[all])
#   Downloading aiofiles-25.1.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting protobuf (from orbax-checkpoint->flax>=0.5.0->gymnasium[all])
#   Downloading protobuf-7.34.1-cp310-abi3-macosx_10_9_universal2.whl.metadata (595 bytes)
# Collecting humanize (from orbax-checkpoint->flax>=0.5.0->gymnasium[all])
#   Downloading humanize-4.15.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting simplejson>=3.16.0 (from orbax-checkpoint->flax>=0.5.0->gymnasium[all])
#   Downloading simplejson-4.1.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Requirement already satisfied: psutil in /Users/mihansgambit/Desktop/code/.venv/lib/python3.12/site-packages (from orbax-checkpoint->flax>=0.5.0->gymnasium[all]) (7.2.2)
# Collecting uvloop (from orbax-checkpoint->flax>=0.5.0->gymnasium[all])
#   Downloading uvloop-0.22.1-cp312-cp312-macosx_10_13_universal2.whl.metadata (4.9 kB)
# Using cached gymnasium-1.3.0-py3-none-any.whl (953 kB)
# Downloading swig-4.4.1-py3-none-macosx_10_9_universal2.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 11.3 MB/s  0:00:00 eta 0:00:01
# Downloading ale_py-0.11.2-cp312-cp312-macosx_13_0_arm64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 23.5 MB/s  0:00:00
# Downloading array_api_compat-1.14.0-py3-none-any.whl (60 kB)
# Using cached cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Using cached farama_notifications-0.0.6-py3-none-any.whl (2.9 kB)
# Downloading flax-0.12.7-py3-none-any.whl (525 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 525.1/525.1 kB 18.7 MB/s  0:00:00
# Downloading imageio-2.37.3-py3-none-any.whl (317 kB)
# Downloading jax-0.10.0-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 25.3 MB/s  0:00:00
# Downloading jaxlib-0.10.0-cp312-cp312-macosx_11_0_arm64.whl (60.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 MB 2.1 MB/s  0:00:28m0:00:0100:01m
# Downloading matplotlib-3.10.9-cp312-cp312-macosx_11_0_arm64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 1.0 MB/s  0:00:08 eta 0:00:010m
# Downloading contourpy-1.3.3-cp312-cp312-macosx_11_0_arm64.whl (273 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp312-cp312-macosx_10_13_universal2.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 775.0 kB/s  0:00:03 eta 0:00:01
# Downloading kiwisolver-1.5.0-cp312-cp312-macosx_11_0_arm64.whl (64 kB)
# Using cached ml_dtypes-0.5.4-cp312-cp312-macosx_10_13_universal2.whl (676 kB)
# Downloading moviepy-2.2.1-py3-none-any.whl (129 kB)
# Downloading pillow-11.3.0-cp312-cp312-macosx_11_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 1.4 MB/s  0:00:03 eta 0:00:01
# Downloading proglog-0.1.12-py3-none-any.whl (6.3 kB)
# Downloading imageio_ffmpeg-0.6.0-py3-none-macosx_11_0_arm64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 1.3 MB/s  0:00:16m0:00:0100:01
# Downloading mujoco-3.8.0-cp312-cp312-macosx_11_0_arm64.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 1.8 MB/s  0:00:03m0:00:0100:01
# Downloading numpy-2.4.4-cp312-cp312-macosx_14_0_arm64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 1.3 MB/s  0:00:04 eta 0:00:010m
# Downloading opencv_python-4.13.0.92-cp37-abi3-macosx_13_0_arm64.whl (46.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 MB 1.8 MB/s  0:00:26m0:00:0100:01
# Downloading pygame_ce-2.5.7-cp312-cp312-macosx_10_13_universal2.whl (17.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 1.1 MB/s  0:00:15m0:00:0100:01
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading pyyaml-6.0.3-cp312-cp312-macosx_11_0_arm64.whl (173 kB)
# Using cached rich-15.0.0-py3-none-any.whl (310 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached scipy-1.17.1-cp312-cp312-macosx_14_0_arm64.whl (20.3 MB)
# Downloading treescope-0.1.10-py3-none-any.whl (182 kB)
# Using cached absl_py-2.4.0-py3-none-any.whl (135 kB)
# Downloading etils-1.14.0-py3-none-any.whl (172 kB)
# Downloading glfw-2.10.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.py39.py310.py311.py312.py313.py314-none-macosx_11_0_arm64.whl (102 kB)
# Downloading msgpack-1.1.2-cp312-cp312-macosx_11_0_arm64.whl (85 kB)
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading optax-0.2.8-py3-none-any.whl (402 kB)
# Downloading orbax_checkpoint-0.11.36-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 1.2 MB/s  0:00:00 eta 0:00:01
# Downloading simplejson-4.1.1-cp312-cp312-macosx_11_0_arm64.whl (91 kB)
# Downloading tensorstore-0.1.82-cp312-cp312-macosx_11_0_arm64.whl (14.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 1.6 MB/s  0:00:09m0:00:0100:01
# Downloading aiofiles-25.1.0-py3-none-any.whl (14 kB)
# Downloading humanize-4.15.0-py3-none-any.whl (132 kB)
# Downloading protobuf-7.34.1-cp310-abi3-macosx_10_9_universal2.whl (429 kB)
# Downloading pyopengl-3.1.10-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 1.2 MB/s  0:00:02 eta 0:00:01
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading uvloop-0.22.1-cp312-cp312-macosx_10_13_universal2.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 1.4 MB/s  0:00:00 eta 0:00:01
# Downloading zipp-3.23.1-py3-none-any.whl (10 kB)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for box2d-py (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [29 lines of output]
#       Using setuptools (version 82.0.1).
#       /private/var/folders/6_/gwk723d11tz3jmpqhzydnpfh0000gn/T/pip-build-env-_1ndlu60/overlay/lib/python3.12/site-packages/setuptools/_distutils/dist.py:287: UserWarning: Unknown distribution option: 'test_suite'
#         warnings.warn(msg)
#       /private/var/folders/6_/gwk723d11tz3jmpqhzydnpfh0000gn/T/pip-build-env-_1ndlu60/overlay/lib/python3.12/site-packages/setuptools/dist.py:765: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#       !!
#
#               ********************************************************************************
#               Please consider removing the following classifiers in favor of a SPDX license expression:
#
#               License :: OSI Approved :: zlib/libpng License
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         self._finalize_license_expression()
#       running bdist_wheel
#       running build
#       running build_py
#       creating build/lib.macosx-26.0-arm64-cpython-312/Box2D
#       copying library/Box2D/Box2D.py -> build/lib.macosx-26.0-arm64-cpython-312/Box2D
#       copying library/Box2D/__init__.py -> build/lib.macosx-26.0-arm64-cpython-312/Box2D
#       creating build/lib.macosx-26.0-arm64-cpython-312/Box2D/b2
#       copying library/Box2D/b2/__init__.py -> build/lib.macosx-26.0-arm64-cpython-312/Box2D/b2
#       running build_ext
#       building 'Box2D._Box2D' extension
#       swigging Box2D/Box2D.i to Box2D/Box2D_wrap.cpp
#       swig -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library/Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D/Box2D_wrap.cpp Box2D/Box2D.i
#       error: command 'swig' failed: No such file or directory
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for box2d-py
# Failed to build box2d-py
# error: failed-wheel-build-for-install
#
# × Failed to build installable wheels for some pyproject.toml based projects
# ╰─> box2d-py
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys, os
if 'google.colab' in sys.modules and not os.path.exists('.setup_complete'):
    # !wget -q https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/setup_colab.sh -O- | bash
    # !wget -q https://raw.githubusercontent.com/yandexdataschool/Practical_RL/master/week02_value_based/mdp.py
    # !touch .setup_complete

# This code creates a virtual display to draw game images on.
# It will have no effect if your machine has a monitor.
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY")) == 0:
    # !bash ../xvfb start
    os.environ['DISPLAY'] = ':1'

# %%
transition_probs = {
    's0': {
        'a0': {'s0': 0.5, 's2': 0.5},
        'a1': {'s2': 1}
    },
    's1': {
        'a0': {'s0': 0.7, 's1': 0.1, 's2': 0.2},
        'a1': {'s1': 0.95, 's2': 0.05}
    },
    's2': {
        'a0': {'s0': 0.4, 's2': 0.6},
        'a1': {'s0': 0.3, 's1': 0.3, 's2': 0.4}
    }
}
rewards = {
    's1': {'a0': {'s0': +5}},
    's2': {'a1': {'s0': -1}}
}

from mdp import MDP
mdp = MDP(transition_probs, rewards, initial_state='s0')
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %% [markdown]
# We can now use MDP just as any other gym environment:

# %%
print('initial state =', mdp.reset())
next_state, reward, done, info = mdp.step('a1')
print('next_state = %s, reward = %s, done = %s' % (next_state, reward, done))
# Out:
# initial state = s0
# next_state = s2, reward = 0.0, done = False

# %% [markdown]
# but it also has other methods that you'll need for Value Iteration

# %%
print("mdp.get_all_states =", mdp.get_all_states())
print("mdp.get_possible_actions('s1') = ", mdp.get_possible_actions('s1'))
print("mdp.get_next_states('s1', 'a0') = ", mdp.get_next_states('s1', 'a0'))
print("mdp.get_reward('s1', 'a0', 's0') = ", mdp.get_reward('s1', 'a0', 's0'))
print("mdp.get_transition_prob('s1', 'a0', 's0') = ", mdp.get_transition_prob('s1', 'a0', 's0'))
# Out:
# mdp.get_all_states = ('s0', 's1', 's2')
# mdp.get_possible_actions('s1') =  ('a0', 'a1')
# mdp.get_next_states('s1', 'a0') =  {'s0': 0.7, 's1': 0.1, 's2': 0.2}
# mdp.get_reward('s1', 'a0', 's0') =  5
# mdp.get_transition_prob('s1', 'a0', 's0') =  0.7

# %% [markdown]
# ### Optional: Visualizing MDPs
#
# You can also visualize any MDP with the drawing fuction donated by [neer201](https://github.com/neer201).
#
# You have to install graphviz for system and for python.
#
# 1. * For ubuntu just run: `sudo apt-get install graphviz`
#    * For OSX: `brew install graphviz`
# 2. `pip install graphviz`
# 3. restart the notebook
#
# __Note:__ Installing graphviz on some OS (esp. Windows) may be tricky. However, you can ignore this part alltogether and use the standart vizualization.

# %%
from mdp import has_graphviz
from IPython.display import display
print("Graphviz available:", has_graphviz)
# Out:
# Graphviz available: False

# %%
if has_graphviz:
    from mdp import plot_graph, plot_graph_with_state_values, plot_graph_optimal_strategy_and_state_values
    display(plot_graph(mdp))

# %% [markdown]
# ### Value Iteration
#
# Now let's build something to solve this MDP. The simplest algorithm so far is __V__alue __I__teration
#
# Here's the pseudo-code for VI:
#
# ---
#
# `1.` Initialize $V^{(0)}(s)=0$, for all $s$
#
# `2.` For $i=0, 1, 2, \dots$
#
# `3.` $ \quad V_{(i+1)}(s) = \max_a \sum_{s'} P(s' | s,a) \cdot [ r(s,a,s') + \gamma V_{i}(s')]$, for all $s$
#
# ---

# %% [markdown]
# First, let's write a function to compute the state-action value function $Q^{\pi}$, defined as follows
#
# $$Q_i(s, a) = \sum_{s'} P(s' | s,a) \cdot [ r(s,a,s') + \gamma V_{i}(s')]$$

# %%
def get_action_value(mdp, state_values, state, action, gamma):
    """ Computes Q(s,a) as in formula above """
    all_possible_next_states = mdp.get_next_states(state, action)
    return sum([mdp.get_transition_prob(state, action, next_state) * (mdp.get_reward(state, action, next_state) + gamma * state_values[next_state]) for next_state in all_possible_next_states])

# %%
import numpy as np
test_Vs = {s: i for i, s in enumerate(sorted(mdp.get_all_states()))}
assert np.isclose(get_action_value(mdp, test_Vs, 's2', 'a1', 0.9), 0.69)
assert np.isclose(get_action_value(mdp, test_Vs, 's1', 'a0', 0.9), 3.95)

# %% [markdown]
# Using $Q(s,a)$ we can now define the "next" V(s) for value iteration.
#  $$V_{(i+1)}(s) = \max_a \sum_{s'} P(s' | s,a) \cdot [ r(s,a,s') + \gamma V_{i}(s')] = \max_a Q_i(s,a)$$

# %%
def get_new_state_value(mdp, state_values, state, gamma):
    """ Computes next V(s) as in formula above. Please do not change state_values in process. """
    if mdp.is_terminal(state):
        return 0
    new_state_values = state_values.copy()
    possible_actions = mdp.get_possible_actions(state)
    q_values = [get_action_value(mdp, state_values, state, action, gamma) for action in possible_actions]
    return max(q_values)

# %%
test_Vs_copy = dict(test_Vs)
assert np.isclose(get_new_state_value(mdp, test_Vs, 's0', 0.9), 1.8)
assert np.isclose(get_new_state_value(mdp, test_Vs, 's2', 0.9), 1.08)
assert np.isclose(get_new_state_value(mdp, {'s0': -1e10, 's1': 0, 's2': -2e10}, 's0', 0.9), -13500000000.0), \
    "Please ensure that you handle negative Q-values of arbitrary magnitude correctly"
assert test_Vs == test_Vs_copy, "Please do not change state_values in get_new_state_value"

# %% [markdown]
# Finally, let's combine everything we wrote into a working value iteration algo.

# %%
# parameters
gamma = 0.9            # discount for MDP
num_iter = 100         # maximum iterations, excluding initialization
# stop VI if new values are this close to old values (or closer)
min_difference = 0.001

# initialize V(s)
state_values = {s: 0 for s in mdp.get_all_states()}

if has_graphviz:
    display(plot_graph_with_state_values(mdp, state_values))

for i in range(num_iter):

    # Compute new state values using the functions you defined above.
    # It must be a dict {state : float V_new(state)}
    new_state_values = {state: get_new_state_value(mdp, state_values, state, gamma) for state in mdp.get_all_states()}

    assert isinstance(new_state_values, dict)

    # Compute difference
    diff = max(abs(new_state_values[s] - state_values[s])
               for s in mdp.get_all_states())
    print("iter %4i   |   diff: %6.5f   |   " % (i, diff), end="")
    print('   '.join("V(%s) = %.3f" % (s, v) for s, v in state_values.items()))
    state_values = new_state_values

    if diff < min_difference:
        print("Terminated")
        break
# Out:
# iter    0   |   diff: 3.50000   |   V(s0) = 0.000   V(s1) = 0.000   V(s2) = 0.000
# iter    1   |   diff: 0.64500   |   V(s0) = 0.000   V(s1) = 3.500   V(s2) = 0.000
# iter    2   |   diff: 0.58050   |   V(s0) = 0.000   V(s1) = 3.815   V(s2) = 0.645
# iter    3   |   diff: 0.43582   |   V(s0) = 0.581   V(s1) = 3.959   V(s2) = 0.962
# iter    4   |   diff: 0.30634   |   V(s0) = 0.866   V(s1) = 4.395   V(s2) = 1.272
# iter    5   |   diff: 0.27571   |   V(s0) = 1.145   V(s1) = 4.670   V(s2) = 1.579
# iter    6   |   diff: 0.24347   |   V(s0) = 1.421   V(s1) = 4.926   V(s2) = 1.838
# iter    7   |   diff: 0.21419   |   V(s0) = 1.655   V(s1) = 5.169   V(s2) = 2.075
# iter    8   |   diff: 0.19277   |   V(s0) = 1.868   V(s1) = 5.381   V(s2) = 2.290
# iter    9   |   diff: 0.17327   |   V(s0) = 2.061   V(s1) = 5.573   V(s2) = 2.481
# iter   10   |   diff: 0.15569   |   V(s0) = 2.233   V(s1) = 5.746   V(s2) = 2.654
# iter   11   |   diff: 0.14012   |   V(s0) = 2.389   V(s1) = 5.902   V(s2) = 2.810
# iter   12   |   diff: 0.12610   |   V(s0) = 2.529   V(s1) = 6.042   V(s2) = 2.950
# iter   13   |   diff: 0.11348   |   V(s0) = 2.655   V(s1) = 6.168   V(s2) = 3.076
# iter   14   |   diff: 0.10213   |   V(s0) = 2.769   V(s1) = 6.282   V(s2) = 3.190
# iter   15   |   diff: 0.09192   |   V(s0) = 2.871   V(s1) = 6.384   V(s2) = 3.292
# iter   16   |   diff: 0.08272   |   V(s0) = 2.963   V(s1) = 6.476   V(s2) = 3.384
# iter   17   |   diff: 0.07445   |   V(s0) = 3.045   V(s1) = 6.558   V(s2) = 3.467
# iter   18   |   diff: 0.06701   |   V(s0) = 3.120   V(s1) = 6.633   V(s2) = 3.541
# iter   19   |   diff: 0.06031   |   V(s0) = 3.187   V(s1) = 6.700   V(s2) = 3.608
# iter   20   |   diff: 0.05428   |   V(s0) = 3.247   V(s1) = 6.760   V(s2) = 3.668
# iter   21   |   diff: 0.04885   |   V(s0) = 3.301   V(s1) = 6.814   V(s2) = 3.723
# iter   22   |   diff: 0.04396   |   V(s0) = 3.350   V(s1) = 6.863   V(s2) = 3.771
# iter   23   |   diff: 0.03957   |   V(s0) = 3.394   V(s1) = 6.907   V(s2) = 3.815
# iter   24   |   diff: 0.03561   |   V(s0) = 3.434   V(s1) = 6.947   V(s2) = 3.855
# iter   25   |   diff: 0.03205   |   V(s0) = 3.469   V(s1) = 6.982   V(s2) = 3.891
# iter   26   |   diff: 0.02884   |   V(s0) = 3.502   V(s1) = 7.014   V(s2) = 3.923
# iter   27   |   diff: 0.02596   |   V(s0) = 3.530   V(s1) = 7.043   V(s2) = 3.951
# iter   28   |   diff: 0.02336   |   V(s0) = 3.556   V(s1) = 7.069   V(s2) = 3.977
# iter   29   |   diff: 0.02103   |   V(s0) = 3.580   V(s1) = 7.093   V(s2) = 4.001
# iter   30   |   diff: 0.01892   |   V(s0) = 3.601   V(s1) = 7.114   V(s2) = 4.022
# iter   31   |   diff: 0.01703   |   V(s0) = 3.620   V(s1) = 7.133   V(s2) = 4.041
# iter   32   |   diff: 0.01533   |   V(s0) = 3.637   V(s1) = 7.150   V(s2) = 4.058
# iter   33   |   diff: 0.01380   |   V(s0) = 3.652   V(s1) = 7.165   V(s2) = 4.073
# iter   34   |   diff: 0.01242   |   V(s0) = 3.666   V(s1) = 7.179   V(s2) = 4.087
# iter   35   |   diff: 0.01117   |   V(s0) = 3.678   V(s1) = 7.191   V(s2) = 4.099
# iter   36   |   diff: 0.01006   |   V(s0) = 3.689   V(s1) = 7.202   V(s2) = 4.110
# iter   37   |   diff: 0.00905   |   V(s0) = 3.699   V(s1) = 7.212   V(s2) = 4.121
# iter   38   |   diff: 0.00815   |   V(s0) = 3.708   V(s1) = 7.221   V(s2) = 4.130
# iter   39   |   diff: 0.00733   |   V(s0) = 3.717   V(s1) = 7.230   V(s2) = 4.138
# iter   40   |   diff: 0.00660   |   V(s0) = 3.724   V(s1) = 7.237   V(s2) = 4.145
# iter   41   |   diff: 0.00594   |   V(s0) = 3.731   V(s1) = 7.244   V(s2) = 4.152
# iter   42   |   diff: 0.00534   |   V(s0) = 3.736   V(s1) = 7.249   V(s2) = 4.158
# iter   43   |   diff: 0.00481   |   V(s0) = 3.742   V(s1) = 7.255   V(s2) = 4.163
# iter   44   |   diff: 0.00433   |   V(s0) = 3.747   V(s1) = 7.260   V(s2) = 4.168
# iter   45   |   diff: 0.00390   |   V(s0) = 3.751   V(s1) = 7.264   V(s2) = 4.172
# iter   46   |   diff: 0.00351   |   V(s0) = 3.755   V(s1) = 7.268   V(s2) = 4.176
# iter   47   |   diff: 0.00316   |   V(s0) = 3.758   V(s1) = 7.271   V(s2) = 4.179
# iter   48   |   diff: 0.00284   |   V(s0) = 3.762   V(s1) = 7.275   V(s2) = 4.183
# iter   49   |   diff: 0.00256   |   V(s0) = 3.764   V(s1) = 7.277   V(s2) = 4.185
# iter   50   |   diff: 0.00230   |   V(s0) = 3.767   V(s1) = 7.280   V(s2) = 4.188
# iter   51   |   diff: 0.00207   |   V(s0) = 3.769   V(s1) = 7.282   V(s2) = 4.190
# iter   52   |   diff: 0.00186   |   V(s0) = 3.771   V(s1) = 7.284   V(s2) = 4.192
# iter   53   |   diff: 0.00168   |   V(s0) = 3.773   V(s1) = 7.286   V(s2) = 4.194
# iter   54   |   diff: 0.00151   |   V(s0) = 3.775   V(s1) = 7.288   V(s2) = 4.196
# iter   55   |   diff: 0.00136   |   V(s0) = 3.776   V(s1) = 7.289   V(s2) = 4.197
# iter   56   |   diff: 0.00122   |   V(s0) = 3.778   V(s1) = 7.291   V(s2) = 4.199
# iter   57   |   diff: 0.00110   |   V(s0) = 3.779   V(s1) = 7.292   V(s2) = 4.200
# iter   58   |   diff: 0.00099   |   V(s0) = 3.780   V(s1) = 7.293   V(s2) = 4.201
# Terminated

# %%
if has_graphviz:
    display(plot_graph_with_state_values(mdp, state_values))

# %%
print("Final state values:", state_values)

assert abs(state_values['s0'] - 3.781) < 0.01
assert abs(state_values['s1'] - 7.294) < 0.01
assert abs(state_values['s2'] - 4.202) < 0.01
# Out:
# Final state values: {'s0': 3.7810348735476405, 's1': 7.29400642386723, 's2': 4.202140275227049}

# %% [markdown]
# Now let's use those $V^{*}(s)$ to find optimal actions in each state
#
#  $$\pi^*(s) = argmax_a \sum_{s'} P(s' | s,a) \cdot [ r(s,a,s') + \gamma V_{i}(s')] = argmax_a Q_i(s,a)$$
#
# The only difference vs V(s) is that here we take not max but argmax: find action such with maximum Q(s,a).

# %%
import numpy as np

def get_optimal_action(mdp, state_values, state, gamma=0.9):
    """ Finds optimal action using formula above. """
    if mdp.is_terminal(state):
        return None
    all_actions = mdp.get_possible_actions(state)
    ind_best_action = np.array([get_action_value(mdp, state_values, state, action, gamma) for action in all_actions]).argmax()
    return all_actions[ind_best_action]

# %%
assert get_optimal_action(mdp, state_values, 's0', gamma) == 'a1'
assert get_optimal_action(mdp, state_values, 's1', gamma) == 'a0'
assert get_optimal_action(mdp, state_values, 's2', gamma) == 'a1'

assert get_optimal_action(mdp, {'s0': -1e10, 's1': 0, 's2': -2e10}, 's0', 0.9) == 'a0', \
    "Please ensure that you handle negative Q-values of arbitrary magnitude correctly"
assert get_optimal_action(mdp, {'s0': -2e10, 's1': 0, 's2': -1e10}, 's0', 0.9) == 'a1', \
    "Please ensure that you handle negative Q-values of arbitrary magnitude correctly"

# %%
if has_graphviz:
    display(plot_graph_optimal_strategy_and_state_values(mdp, state_values, get_action_value))

# %%
# Measure agent's average reward

s = mdp.reset()
rewards = []
for _ in range(10000):
    s, r, done, _ = mdp.step(get_optimal_action(mdp, state_values, s, gamma))
    rewards.append(r)

print("average reward: ", np.mean(rewards))

assert(0.40 < np.mean(rewards) < 0.55)
# Out:
# average reward:  0.4464

# %% [markdown]
# ### Frozen lake

# %%
from mdp import FrozenLakeEnv
mdp = FrozenLakeEnv(slip_chance=0)

mdp.render()
# Out:
# *FFF
# FHFH
# FFFH
# HFFG

# %%
def value_iteration(mdp, state_values=None, gamma=0.9, num_iter=1000, min_difference=1e-5):
    """ performs num_iter value iteration steps starting from state_values. Same as before but in a function """
    state_values = state_values or {s: 0 for s in mdp.get_all_states()}
    for i in range(num_iter):

        # Compute new state values using the functions you defined above. It must be a dict {state : new_V(state)}
        new_state_values = {state: get_new_state_value(mdp, state_values, state, gamma) for state in mdp.get_all_states()}

        assert isinstance(new_state_values, dict)

        # Compute difference
        diff = max(abs(new_state_values[s] - state_values[s])
                   for s in mdp.get_all_states())

        print("iter %4i   |   diff: %6.5f   |   V(start): %.3f " %
              (i, diff, new_state_values[mdp._initial_state]))

        state_values = new_state_values
        if diff < min_difference:
            break

    return state_values

# %%
state_values = value_iteration(mdp)
# Out:
# iter    0   |   diff: 1.00000   |   V(start): 0.000
# iter    1   |   diff: 0.90000   |   V(start): 0.000
# iter    2   |   diff: 0.81000   |   V(start): 0.000
# iter    3   |   diff: 0.72900   |   V(start): 0.000
# iter    4   |   diff: 0.65610   |   V(start): 0.000
# iter    5   |   diff: 0.59049   |   V(start): 0.590
# iter    6   |   diff: 0.00000   |   V(start): 0.590

# %%
s = mdp.reset()
mdp.render()
for t in range(100):
    a = get_optimal_action(mdp, state_values, s, gamma)
    print(a, end='\n\n')
    s, r, done, _ = mdp.step(a)
    mdp.render()
    if done:
        break
# Out:
# *FFF
# FHFH
# FFFH
# HFFG
#
# down
#
# SFFF
# *HFH
# FFFH
# HFFG
#
# down
#
# SFFF
# FHFH
# *FFH
# HFFG
#
# right
#
# SFFF
# FHFH
# F*FH
# HFFG
#
# down
#
# SFFF
# FHFH
# FFFH
# H*FG
#
# right
#
# SFFF
# FHFH
# FFFH
# HF*G
#
# right
#
# SFFF
# FHFH
# FFFH
# HFF*

# %% [markdown]
# ### Let's visualize!
#
# It's usually interesting to see what your algorithm actually learned under the hood. To do so, we'll plot state value functions and optimal actions at each VI step.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline


def draw_policy(mdp, state_values):
    plt.figure(figsize=(3, 3))
    h, w = mdp.desc.shape
    states = sorted(mdp.get_all_states())
    V = np.array([state_values[s] for s in states])
    Pi = {s: get_optimal_action(mdp, state_values, s, gamma) for s in states}
    plt.imshow(V.reshape(w, h), cmap='gray', interpolation='none', clim=(0, 1))
    ax = plt.gca()
    ax.set_xticks(np.arange(h)-.5)
    ax.set_yticks(np.arange(w)-.5)
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    Y, X = np.mgrid[0:4, 0:4]
    a2uv = {'left': (-1, 0), 'down': (0, -1), 'right': (1, 0), 'up': (0, 1)}
    for y in range(h):
        for x in range(w):
            plt.text(x, y, str(mdp.desc[y, x].item()),
                     color='g', size=12,  verticalalignment='center',
                     horizontalalignment='center', fontweight='bold')
            a = Pi[y, x]
            if a is None:
                continue
            u, v = a2uv[a]
            plt.arrow(x, y, u*.3, -v*.3, color='m',
                      head_width=0.1, head_length=0.1)
    plt.grid(color='b', lw=2, ls='-')
    plt.show()

# %%
state_values = {s: 0 for s in mdp.get_all_states()}

for i in range(10):
    print("after iteration %i" % i)
    state_values = value_iteration(mdp, state_values, num_iter=1)
    draw_policy(mdp, state_values)
# please ignore iter 0 at each step
# Out:
# after iteration 0
# iter    0   |   diff: 1.00000   |   V(start): 0.000
# after iteration 1
# iter    0   |   diff: 0.90000   |   V(start): 0.000
# after iteration 2
# iter    0   |   diff: 0.81000   |   V(start): 0.000
# after iteration 3
# iter    0   |   diff: 0.72900   |   V(start): 0.000
# after iteration 4
# iter    0   |   diff: 0.65610   |   V(start): 0.000
# after iteration 5
# iter    0   |   diff: 0.59049   |   V(start): 0.590
# after iteration 6
# iter    0   |   diff: 0.00000   |   V(start): 0.590
# after iteration 7
# iter    0   |   diff: 0.00000   |   V(start): 0.590
# after iteration 8
# iter    0   |   diff: 0.00000   |   V(start): 0.590
# after iteration 9
# iter    0   |   diff: 0.00000   |   V(start): 0.590

# %%
from IPython.display import clear_output
from time import sleep
mdp = FrozenLakeEnv(map_name='8x8', slip_chance=0.1)
state_values = {s: 0 for s in mdp.get_all_states()}

for i in range(30):
    clear_output(True)
    print("after iteration %i" % i)
    state_values = value_iteration(mdp, state_values, num_iter=1)
    draw_policy(mdp, state_values)
    sleep(0.5)
# please ignore iter 0 at each step
# Out:
# after iteration 29
# iter    0   |   diff: 0.00000   |   V(start): 0.198

# %% [markdown]
# Massive tests

# %%
mdp = FrozenLakeEnv(slip_chance=0)
state_values = value_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    rewards = []
    for t in range(100):
        s, r, done, _ = mdp.step(
            get_optimal_action(mdp, state_values, s, gamma))
        rewards.append(r)
        if done:
            break
    total_rewards.append(np.sum(rewards))

print("average reward: ", np.mean(total_rewards))
assert(1.0 <= np.mean(total_rewards) <= 1.0)
print("Well done!")
# Out:
# iter    0   |   diff: 1.00000   |   V(start): 0.000
# iter    1   |   diff: 0.90000   |   V(start): 0.000
# iter    2   |   diff: 0.81000   |   V(start): 0.000
# iter    3   |   diff: 0.72900   |   V(start): 0.000
# iter    4   |   diff: 0.65610   |   V(start): 0.000
# iter    5   |   diff: 0.59049   |   V(start): 0.590
# iter    6   |   diff: 0.00000   |   V(start): 0.590
# average reward:  1.0
# Well done!

# %%
# Measure agent's average reward
mdp = FrozenLakeEnv(slip_chance=0.1)
state_values = value_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    rewards = []
    for t in range(100):
        s, r, done, _ = mdp.step(
            get_optimal_action(mdp, state_values, s, gamma))
        rewards.append(r)
        if done:
            break
    total_rewards.append(np.sum(rewards))

print("average reward: ", np.mean(total_rewards))
assert(0.8 <= np.mean(total_rewards) <= 0.95)
print("Well done!")
# Out:
# iter    0   |   diff: 0.90000   |   V(start): 0.000
# iter    1   |   diff: 0.72900   |   V(start): 0.000
# iter    2   |   diff: 0.62330   |   V(start): 0.000
# iter    3   |   diff: 0.50487   |   V(start): 0.000
# iter    4   |   diff: 0.40894   |   V(start): 0.000
# iter    5   |   diff: 0.34868   |   V(start): 0.349
# iter    6   |   diff: 0.06529   |   V(start): 0.410
# iter    7   |   diff: 0.05832   |   V(start): 0.468
# iter    8   |   diff: 0.01139   |   V(start): 0.480
# iter    9   |   diff: 0.00764   |   V(start): 0.487
# iter   10   |   diff: 0.00164   |   V(start): 0.489
# iter   11   |   diff: 0.00094   |   V(start): 0.490
# iter   12   |   diff: 0.00022   |   V(start): 0.490
# iter   13   |   diff: 0.00011   |   V(start): 0.490
# iter   14   |   diff: 0.00003   |   V(start): 0.490
# iter   15   |   diff: 0.00001   |   V(start): 0.490
# iter   16   |   diff: 0.00000   |   V(start): 0.490
# average reward:  0.877
# Well done!

# %%
# Measure agent's average reward
mdp = FrozenLakeEnv(slip_chance=0.25)
state_values = value_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    rewards = []
    for t in range(100):
        s, r, done, _ = mdp.step(
            get_optimal_action(mdp, state_values, s, gamma))
        rewards.append(r)
        if done:
            break
    total_rewards.append(np.sum(rewards))

print("average reward: ", np.mean(total_rewards))
assert(0.6 <= np.mean(total_rewards) <= 0.7)
print("Well done!")
# Out:
# iter    0   |   diff: 0.75000   |   V(start): 0.000
# iter    1   |   diff: 0.50625   |   V(start): 0.000
# iter    2   |   diff: 0.39867   |   V(start): 0.000
# iter    3   |   diff: 0.26910   |   V(start): 0.000
# iter    4   |   diff: 0.18164   |   V(start): 0.000
# iter    5   |   diff: 0.14013   |   V(start): 0.140
# iter    6   |   diff: 0.07028   |   V(start): 0.199
# iter    7   |   diff: 0.06030   |   V(start): 0.260
# iter    8   |   diff: 0.02594   |   V(start): 0.285
# iter    9   |   diff: 0.01918   |   V(start): 0.305
# iter   10   |   diff: 0.00858   |   V(start): 0.313
# iter   11   |   diff: 0.00560   |   V(start): 0.319
# iter   12   |   diff: 0.00260   |   V(start): 0.321
# iter   13   |   diff: 0.00159   |   V(start): 0.323
# iter   14   |   diff: 0.00076   |   V(start): 0.324
# iter   15   |   diff: 0.00045   |   V(start): 0.324
# iter   16   |   diff: 0.00022   |   V(start): 0.324
# iter   17   |   diff: 0.00012   |   V(start): 0.325
# iter   18   |   diff: 0.00006   |   V(start): 0.325
# iter   19   |   diff: 0.00003   |   V(start): 0.325
# iter   20   |   diff: 0.00002   |   V(start): 0.325
# iter   21   |   diff: 0.00001   |   V(start): 0.325
# average reward:  0.622
# Well done!

# %%
# Measure agent's average reward
mdp = FrozenLakeEnv(slip_chance=0.2, map_name='8x8')
state_values = value_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    rewards = []
    for t in range(100):
        s, r, done, _ = mdp.step(
            get_optimal_action(mdp, state_values, s, gamma))
        rewards.append(r)
        if done:
            break
    total_rewards.append(np.sum(rewards))

print("average reward: ", np.mean(total_rewards))
assert(0.6 <= np.mean(total_rewards) <= 0.8)
print("Well done!")
# Out:
# iter    0   |   diff: 0.80000   |   V(start): 0.000
# iter    1   |   diff: 0.57600   |   V(start): 0.000
# iter    2   |   diff: 0.41472   |   V(start): 0.000
# iter    3   |   diff: 0.29860   |   V(start): 0.000
# iter    4   |   diff: 0.24186   |   V(start): 0.000
# iter    5   |   diff: 0.19349   |   V(start): 0.000
# iter    6   |   diff: 0.15325   |   V(start): 0.000
# iter    7   |   diff: 0.12288   |   V(start): 0.000
# iter    8   |   diff: 0.09930   |   V(start): 0.000
# iter    9   |   diff: 0.08037   |   V(start): 0.000
# iter   10   |   diff: 0.06426   |   V(start): 0.000
# iter   11   |   diff: 0.05129   |   V(start): 0.000
# iter   12   |   diff: 0.04330   |   V(start): 0.000
# iter   13   |   diff: 0.03802   |   V(start): 0.033
# iter   14   |   diff: 0.03332   |   V(start): 0.058
# iter   15   |   diff: 0.02910   |   V(start): 0.087
# iter   16   |   diff: 0.01855   |   V(start): 0.106
# iter   17   |   diff: 0.01403   |   V(start): 0.120
# iter   18   |   diff: 0.00810   |   V(start): 0.128
# iter   19   |   diff: 0.00555   |   V(start): 0.133
# iter   20   |   diff: 0.00321   |   V(start): 0.137
# iter   21   |   diff: 0.00247   |   V(start): 0.138
# iter   22   |   diff: 0.00147   |   V(start): 0.139
# iter   23   |   diff: 0.00104   |   V(start): 0.140
# iter   24   |   diff: 0.00058   |   V(start): 0.140
# iter   25   |   diff: 0.00036   |   V(start): 0.141
# iter   26   |   diff: 0.00024   |   V(start): 0.141
# iter   27   |   diff: 0.00018   |   V(start): 0.141
# iter   28   |   diff: 0.00012   |   V(start): 0.141
# iter   29   |   diff: 0.00007   |   V(start): 0.141
# iter   30   |   diff: 0.00004   |   V(start): 0.141
# iter   31   |   diff: 0.00003   |   V(start): 0.141
# iter   32   |   diff: 0.00001   |   V(start): 0.141
# iter   33   |   diff: 0.00001   |   V(start): 0.141
# average reward:  0.74
# Well done!

# %% [markdown]
# # HW Part 1: Value iteration convergence
#
# ### Find an MDP for which value iteration takes long to converge  (1 pts)
#
# When we ran value iteration on the small frozen lake problem, the last iteration where an action changed was iteration 6--i.e., value iteration computed the optimal policy at iteration 6. Are there any guarantees regarding how many iterations it'll take value iteration to compute the optimal policy? There are no such guarantees without additional assumptions--we can construct the MDP in such a way that the greedy policy will change after arbitrarily many iterations.
#
# Your task: define an MDP with at most 3 states and 2 actions, such that when you run value iteration, the optimal action changes at iteration >= 50. Use discount=0.95. (However, note that the discount doesn't matter here--you can construct an appropriate MDP with any discount.)
#
# Note: value function must change at least once after iteration >=50, not necessarily change on every iteration till >=50.

# %%
transition_probs = {
    's0': {
        'a0': {'s1': 1, 's2': 0},
        'a1': {'s1': 0, 's2': 1}
    },
    's1': {
        'a0': {'s0': 1},
        'a1': {'s0': 1}
    },
    's2': {
        'a0': {'s0': 1},
        'a1': {'s0': 1}
    }
}
rewards = {
    's0': {'a0': {'s1': 1, 's2': 0}, 'a1': {'s1': 0, 's2': 1}},
    's1': {'a0': {'s0': -1}},
    's2': {'a1': {'s0': -1}}
}

from mdp import MDP
from numpy import random
mdp = MDP(transition_probs, rewards, initial_state=random.choice(tuple(transition_probs.keys())))
# Feel free to change the initial_state

# %%
state_values = {s: 0 for s in mdp.get_all_states()}
gamma=0.95
policy = np.array([get_optimal_action(mdp, state_values, state, gamma)
                   for state in sorted(mdp.get_all_states())])

for i in range(100):
    print("after iteration %i" % i)
    state_values = value_iteration(mdp, state_values, num_iter=1, gamma=gamma)

    new_policy = np.array([get_optimal_action(mdp, state_values, state, gamma)
                           for state in sorted(mdp.get_all_states())])

    n_changes = (policy != new_policy).sum()
    print("N actions changed = %i \n" % n_changes)
    policy = new_policy

# please ignore iter 0 at each step
# Out:
# after iteration 0
# iter    0   |   diff: 1.00000   |   V(start): 0.000
# N actions changed = 0
#
# after iteration 1
# iter    0   |   diff: 0.95000   |   V(start): 0.950
# N actions changed = 0
#
# after iteration 2
# iter    0   |   diff: 0.90250   |   V(start): 0.950
# N actions changed = 0
#
# after iteration 3
# iter    0   |   diff: 0.85737   |   V(start): 1.807
# N actions changed = 0
#
# after iteration 4
# iter    0   |   diff: 0.81451   |   V(start): 1.807
# N actions changed = 0
#
# after iteration 5
# iter    0   |   diff: 0.77378   |   V(start): 2.581
# N actions changed = 0
#
# after iteration 6
# iter    0   |   diff: 0.73509   |   V(start): 2.581
# N actions changed = 0
#
# after iteration 7
# iter    0   |   diff: 0.69834   |   V(start): 3.279
# N actions changed = 0
#
# after iteration 8
# iter    0   |   diff: 0.66342   |   V(start): 3.279
# N actions changed = 0
#
# after iteration 9
# iter    0   |   diff: 0.63025   |   V(start): 3.910
# N actions changed = 0
#
# after iteration 10
# iter    0   |   diff: 0.59874   |   V(start): 3.910
# N actions changed = 0
#
# after iteration 11
# iter    0   |   diff: 0.56880   |   V(start): 4.479
# N actions changed = 0
#
# after iteration 12
# iter    0   |   diff: 0.54036   |   V(start): 4.479
# N actions changed = 0
#
# after iteration 13
# iter    0   |   diff: 0.51334   |   V(start): 4.992
# N actions changed = 0
#
# after iteration 14
# iter    0   |   diff: 0.48767   |   V(start): 4.992
# N actions changed = 0
#
# after iteration 15
# iter    0   |   diff: 0.46329   |   V(start): 5.455
# N actions changed = 0
#
# after iteration 16
# iter    0   |   diff: 0.44013   |   V(start): 5.455
# N actions changed = 0
#
# after iteration 17
# iter    0   |   diff: 0.41812   |   V(start): 5.873
# N actions changed = 0
#
# after iteration 18
# iter    0   |   diff: 0.39721   |   V(start): 5.873
# N actions changed = 0
#
# after iteration 19
# iter    0   |   diff: 0.37735   |   V(start): 6.251
# N actions changed = 0
#
# after iteration 20
# iter    0   |   diff: 0.35849   |   V(start): 6.251
# N actions changed = 0
#
# after iteration 21
# iter    0   |   diff: 0.34056   |   V(start): 6.591
# N actions changed = 0
#
# after iteration 22
# iter    0   |   diff: 0.32353   |   V(start): 6.591
# N actions changed = 0
#
# after iteration 23
# iter    0   |   diff: 0.30736   |   V(start): 6.899
# N actions changed = 0
#
# after iteration 24
# iter    0   |   diff: 0.29199   |   V(start): 6.899
# N actions changed = 0
#
# after iteration 25
# iter    0   |   diff: 0.27739   |   V(start): 7.176
# N actions changed = 0
#
# after iteration 26
# iter    0   |   diff: 0.26352   |   V(start): 7.176
# N actions changed = 0
#
# after iteration 27
# iter    0   |   diff: 0.25034   |   V(start): 7.426
# N actions changed = 0
#
# after iteration 28
# iter    0   |   diff: 0.23783   |   V(start): 7.426
# N actions changed = 0
#
# after iteration 29
# iter    0   |   diff: 0.22594   |   V(start): 7.652
# N actions changed = 0
#
# after iteration 30
# iter    0   |   diff: 0.21464   |   V(start): 7.652
# N actions changed = 0
#
# after iteration 31
# iter    0   |   diff: 0.20391   |   V(start): 7.856
# N actions changed = 0
#
# after iteration 32
# iter    0   |   diff: 0.19371   |   V(start): 7.856
# N actions changed = 0
#
# after iteration 33
# iter    0   |   diff: 0.18403   |   V(start): 8.040
# N actions changed = 0
#
# after iteration 34
# iter    0   |   diff: 0.17482   |   V(start): 8.040
# N actions changed = 0
#
# after iteration 35
# iter    0   |   diff: 0.16608   |   V(start): 8.206
# N actions changed = 0
#
# after iteration 36
# iter    0   |   diff: 0.15778   |   V(start): 8.206
# N actions changed = 0
#
# after iteration 37
# iter    0   |   diff: 0.14989   |   V(start): 8.356
# N actions changed = 0
#
# after iteration 38
# iter    0   |   diff: 0.14240   |   V(start): 8.356
# N actions changed = 0
#
# after iteration 39
# iter    0   |   diff: 0.13528   |   V(start): 8.491
# N actions changed = 0
#
# after iteration 40
# iter    0   |   diff: 0.12851   |   V(start): 8.491
# N actions changed = 0
#
# after iteration 41
# iter    0   |   diff: 0.12209   |   V(start): 8.614
# N actions changed = 0
#
# after iteration 42
# iter    0   |   diff: 0.11598   |   V(start): 8.614
# N actions changed = 0
#
# after iteration 43
# iter    0   |   diff: 0.11018   |   V(start): 8.724
# N actions changed = 0
#
# after iteration 44
# iter    0   |   diff: 0.10467   |   V(start): 8.724
# N actions changed = 0
#
# after iteration 45
# iter    0   |   diff: 0.09944   |   V(start): 8.823
# N actions changed = 0
#
# after iteration 46
# iter    0   |   diff: 0.09447   |   V(start): 8.823
# N actions changed = 0
#
# after iteration 47
# iter    0   |   diff: 0.08974   |   V(start): 8.913
# N actions changed = 0
#
# after iteration 48
# iter    0   |   diff: 0.08526   |   V(start): 8.913
# N actions changed = 0
#
# after iteration 49
# iter    0   |   diff: 0.08099   |   V(start): 8.994
# N actions changed = 0
#
# after iteration 50
# iter    0   |   diff: 0.07694   |   V(start): 8.994
# N actions changed = 0
#
# after iteration 51
# iter    0   |   diff: 0.07310   |   V(start): 9.067
# N actions changed = 0
#
# after iteration 52
# iter    0   |   diff: 0.06944   |   V(start): 9.067
# N actions changed = 0
#
# after iteration 53
# iter    0   |   diff: 0.06597   |   V(start): 9.133
# N actions changed = 0
#
# after iteration 54
# iter    0   |   diff: 0.06267   |   V(start): 9.133
# N actions changed = 0
#
# after iteration 55
# iter    0   |   diff: 0.05954   |   V(start): 9.192
# N actions changed = 0
#
# after iteration 56
# iter    0   |   diff: 0.05656   |   V(start): 9.192
# N actions changed = 0
#
# after iteration 57
# iter    0   |   diff: 0.05373   |   V(start): 9.246
# N actions changed = 0
#
# after iteration 58
# iter    0   |   diff: 0.05105   |   V(start): 9.246
# N actions changed = 0
#
# after iteration 59
# iter    0   |   diff: 0.04849   |   V(start): 9.295
# N actions changed = 0
#
# after iteration 60
# iter    0   |   diff: 0.04607   |   V(start): 9.295
# N actions changed = 0
#
# after iteration 61
# iter    0   |   diff: 0.04377   |   V(start): 9.338
# N actions changed = 0
#
# after iteration 62
# iter    0   |   diff: 0.04158   |   V(start): 9.338
# N actions changed = 0
#
# after iteration 63
# iter    0   |   diff: 0.03950   |   V(start): 9.378
# N actions changed = 0
#
# after iteration 64
# iter    0   |   diff: 0.03752   |   V(start): 9.378
# N actions changed = 0
#
# after iteration 65
# iter    0   |   diff: 0.03565   |   V(start): 9.414
# N actions changed = 0
#
# after iteration 66
# iter    0   |   diff: 0.03387   |   V(start): 9.414
# N actions changed = 0
#
# after iteration 67
# iter    0   |   diff: 0.03217   |   V(start): 9.446
# N actions changed = 0
#
# after iteration 68
# iter    0   |   diff: 0.03056   |   V(start): 9.446
# N actions changed = 0
#
# after iteration 69
# iter    0   |   diff: 0.02904   |   V(start): 9.475
# N actions changed = 0
#
# after iteration 70
# iter    0   |   diff: 0.02758   |   V(start): 9.475
# N actions changed = 0
#
# after iteration 71
# iter    0   |   diff: 0.02620   |   V(start): 9.501
# N actions changed = 0
#
# after iteration 72
# iter    0   |   diff: 0.02489   |   V(start): 9.501
# N actions changed = 0
#
# after iteration 73
# iter    0   |   diff: 0.02365   |   V(start): 9.525
# N actions changed = 0
#
# after iteration 74
# iter    0   |   diff: 0.02247   |   V(start): 9.525
# N actions changed = 0
#
# after iteration 75
# iter    0   |   diff: 0.02134   |   V(start): 9.546
# N actions changed = 0
#
# after iteration 76
# iter    0   |   diff: 0.02028   |   V(start): 9.546
# N actions changed = 0
#
# after iteration 77
# iter    0   |   diff: 0.01926   |   V(start): 9.565
# N actions changed = 0
#
# after iteration 78
# iter    0   |   diff: 0.01830   |   V(start): 9.565
# N actions changed = 0
#
# after iteration 79
# iter    0   |   diff: 0.01738   |   V(start): 9.583
# N actions changed = 0
#
# after iteration 80
# iter    0   |   diff: 0.01652   |   V(start): 9.583
# N actions changed = 0
#
# after iteration 81
# iter    0   |   diff: 0.01569   |   V(start): 9.598
# N actions changed = 0
#
# after iteration 82
# iter    0   |   diff: 0.01491   |   V(start): 9.598
# N actions changed = 0
#
# after iteration 83
# iter    0   |   diff: 0.01416   |   V(start): 9.613
# N actions changed = 0
#
# after iteration 84
# iter    0   |   diff: 0.01345   |   V(start): 9.613
# N actions changed = 0
#
# after iteration 85
# iter    0   |   diff: 0.01278   |   V(start): 9.625
# N actions changed = 0
#
# after iteration 86
# iter    0   |   diff: 0.01214   |   V(start): 9.625
# N actions changed = 0
#
# after iteration 87
# iter    0   |   diff: 0.01153   |   V(start): 9.637
# N actions changed = 0
#
# after iteration 88
# iter    0   |   diff: 0.01096   |   V(start): 9.637
# N actions changed = 0
#
# after iteration 89
# iter    0   |   diff: 0.01041   |   V(start): 9.647
# N actions changed = 0
#
# after iteration 90
# iter    0   |   diff: 0.00989   |   V(start): 9.647
# N actions changed = 0
#
# after iteration 91
# iter    0   |   diff: 0.00939   |   V(start): 9.657
# N actions changed = 0
#
# after iteration 92
# iter    0   |   diff: 0.00892   |   V(start): 9.657
# N actions changed = 0
#
# after iteration 93
# iter    0   |   diff: 0.00848   |   V(start): 9.665
# N actions changed = 0
#
# after iteration 94
# iter    0   |   diff: 0.00805   |   V(start): 9.665
# N actions changed = 0
#
# after iteration 95
# iter    0   |   diff: 0.00765   |   V(start): 9.673
# N actions changed = 0
#
# after iteration 96
# iter    0   |   diff: 0.00727   |   V(start): 9.673
# N actions changed = 0
#
# after iteration 97
# iter    0   |   diff: 0.00691   |   V(start): 9.680
# N actions changed = 0
#
# after iteration 98
# iter    0   |   diff: 0.00656   |   V(start): 9.680
# N actions changed = 0
#
# after iteration 99
# iter    0   |   diff: 0.00623   |   V(start): 9.686
# N actions changed = 0

# %% [markdown]
# ### Value iteration convervence proof (1 pts)
# **Note:** Assume that $\mathcal{S}, \mathcal{A}$ are finite.
#
# Update of value function in value iteration can be rewritten in a form of Bellman operator:
#
# $$(TV)(s) = \max_{a \in \mathcal{A}}\mathbb{E}\left[ r_{t+1} + \gamma V(s_{t+1}) | s_t = s, a_t = a\right]$$
#
# Value iteration algorithm with Bellman operator:
#
# ---
# &nbsp;&nbsp; Initialize $V_0$
#
# &nbsp;&nbsp; **for** $k = 0,1,2,...$ **do**
#
# &nbsp;&nbsp;&nbsp;&nbsp; $V_{k+1} \leftarrow TV_k$
#
# &nbsp;&nbsp;**end for**
#
# ---
#
# In [lecture](https://docs.google.com/presentation/d/1lz2oIUTvd2MHWKEQSH8hquS66oe4MZ_eRvVViZs2uuE/edit#slide=id.g4fd6bae29e_2_4) we established contraction property of bellman operator:
#
# $$
# ||TV - TU||_{\infty} \le \gamma ||V - U||_{\infty}
# $$
#
# For all $V, U$
#
# Using contraction property of Bellman operator, Banach fixed-point theorem and Bellman equations prove that value function converges to $V^*$ in value iterateion$
#
# *<-- Your proof here -->*

# %% [markdown]
# ### Asynchronious value iteration (2 pts)
#
# Consider the following algorithm:
#
# ---
#
# Initialize $V_0$
#
# **for** $k = 0,1,2,...$ **do**
#
# &nbsp;&nbsp;&nbsp;&nbsp; Select some state $s_k \in \mathcal{S}$
#
# &nbsp;&nbsp;&nbsp;&nbsp; $V(s_k) := (TV)(s_k)$
#
# **end for**
#
# ---
#
#
# Note that unlike common value iteration, here we update only a single state at a time.
#
# **Homework.** Prove the following proposition:
#
# If for all $s \in \mathcal{S}$, $s$ appears in the sequence $(s_0, s_1, ...)$ infinitely often, then $V$ converges to $V*$
#
# *<-- Your proof here -->*

# %% [markdown]
# # HW Part 2: Policy iteration
#
# ## Policy iteration implementateion (3 pts)
#
# Let's implement exact policy iteration (PI), which has the following pseudocode:
#
# ---
# Initialize $\pi_0$   `// random or fixed action`
#
# For $n=0, 1, 2, \dots$
# - Compute the state-value function $V^{\pi_{n}}$
# - Using $V^{\pi_{n}}$, compute the state-action-value function $Q^{\pi_{n}}$
# - Compute new policy $\pi_{n+1}(s) = \operatorname*{argmax}_a Q^{\pi_{n}}(s,a)$
# ---
#
# Unlike VI, policy iteration has to maintain a policy - chosen actions from all states - and estimate $V^{\pi_{n}}$ based on this policy. It only changes policy once values converged.
#
#
# Below are a few helpers that you may or may not use in your implementation.

# %%
transition_probs = {
    's0': {
        'a0': {'s0': 0.5, 's2': 0.5},
        'a1': {'s2': 1}
    },
    's1': {
        'a0': {'s0': 0.7, 's1': 0.1, 's2': 0.2},
        'a1': {'s1': 0.95, 's2': 0.05}
    },
    's2': {
        'a0': {'s0': 0.4, 's1': 0.6},
        'a1': {'s0': 0.3, 's1': 0.3, 's2': 0.4}
    }
}
rewards = {
    's1': {'a0': {'s0': +5}},
    's2': {'a1': {'s0': -1}}
}

from mdp import MDP
mdp = MDP(transition_probs, rewards, initial_state='s0')

# %% [markdown]
# Let's write a function called `compute_vpi` that computes the state-value function $V^{\pi}$ for an arbitrary policy $\pi$.
#
# Unlike VI, this time you must find the exact solution, not just a single iteration.
#
# Recall that $V^{\pi}$ satisfies the following linear equation:
# $$V^{\pi}(s) = \sum_{s'} P(s,\pi(s),s')[ R(s,\pi(s),s') + \gamma V^{\pi}(s')]$$
#
# You'll have to solve a linear system in your code. (Find an exact solution, e.g., with `np.linalg.solve`.)

# %%
def compute_vpi(mdp, policy, gamma):
    """
    Computes V^pi(s) FOR ALL STATES under given policy.
    :param policy: a dict of currently chosen actions {s : a}
    :returns: a dict {state : V^pi(state) for all states}
    """
    <YOUR CODE>
    return <YOUR CODE>

# %%
test_policy = {s: np.random.choice(
    mdp.get_possible_actions(s)) for s in mdp.get_all_states()}
new_vpi = compute_vpi(mdp, test_policy, gamma)

print(new_vpi)

assert type(
    new_vpi) is dict, "compute_vpi must return a dict {state : V^pi(state) for all states}"

# %% [markdown]
# Once we've got new state values, it's time to update our policy.

# %%
def compute_new_policy(mdp, vpi, gamma):
    """
    Computes new policy as argmax of state values
    :param vpi: a dict {state : V^pi(state) for all states}
    :returns: a dict {state : optimal action for all states}
    """
    <YOUR CODE>
    return <YOUR CODE>

# %%
new_policy = compute_new_policy(mdp, new_vpi, gamma)

print(new_policy)

assert type(
    new_policy) is dict, "compute_new_policy must return a dict {state : optimal action for all states}"

# %% [markdown]
# __Main loop__

# %%
def policy_iteration(mdp, policy=None, gamma=0.9, num_iter=1000, min_difference=1e-5):
    """
    Run the policy iteration loop for num_iter iterations or till difference between V(s) is below min_difference.
    If policy is not given, initialize it at random.
    """
    <YOUR CODE: a whole lot of it>

    return state_values, policy

# %% [markdown]
# __Your PI Results__

# %%
<YOUR CODE: compare PI and VI on the MDP from bonus 1, then on small & large FrozenLake>

# %% [markdown]
# ## Policy iteration convergence (3 pts)
#
# **Note:** Assume that $\mathcal{S}, \mathcal{A}$ are finite.
#
# We can define another Bellman operator:
#
# $$(T_{\pi}V)(s) = \mathbb{E}_{r, s'|s, a = \pi(s)}\left[r + \gamma V(s')\right]$$
#
# And rewrite policy iteration algorithm in operator form:
#
#
# ---
#
# Initialize $\pi_0$
#
# **for** $k = 0,1,2,...$ **do**
#
# &nbsp;&nbsp;&nbsp;&nbsp; Solve $V_k = T_{\pi_k}V_k$
#
# &nbsp;&nbsp;&nbsp;&nbsp; Select $\pi_{k+1}$ s.t. $T_{\pi_{k+1}}V_k = TV_k$
#
# **end for**
#
# ---
#
# To prove convergence of the algorithm we need to prove two properties: contraction an monotonicity.
#
# #### Monotonicity (0.5 pts)
#
# For all $V, U$ if $V(s) \le U(s)$   $\forall s \in \mathcal{S}$ then $(T_\pi V)(s) \le (T_\pi U)(s)$   $\forall s \in  \mathcal{S}$
#
# *<-- Your proof here -->*
#
# #### Contraction (1 pts)
#
# $$
# ||T_\pi V - T_\pi U||_{\infty} \le \gamma ||V - U||_{\infty}
# $$
#
# For all $V, U$
#
# *<-- Your proof here -->*
#
# #### Convergence (1.5 pts)
#
# Prove that there exists iteration $k_0$ such that $\pi_k = \pi^*$ for all $k \ge k_0$
#
# *<-- Your proof here -->*
